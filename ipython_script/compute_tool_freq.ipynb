# %%
import csv
import random
import numpy as np
import json
import warnings
import operator

import h5py
from keras.models import model_from_json
from keras import backend as K

warnings.filterwarnings("ignore")


def format_tool_id(tool_link):
    """
    Extract tool id from tool link
    """
    tool_id_split = tool_link.split("/")
    tool_id = tool_id_split[-2] if len(tool_id_split) > 1 else tool_link
    return tool_id

def read_workflow(wf_id, workflow_rows):
    """
    Read all connections for a workflow
    """
    tool_parents = dict()
    for connection in workflow_rows:
        in_tool = connection[0]
        out_tool = connection[1]
        if out_tool not in tool_parents:
            tool_parents[out_tool] = list()
        if in_tool not in tool_parents[out_tool]:
            tool_parents[out_tool].append(in_tool)
    return tool_parents

def get_roots_leaves(graph):
    roots = list()
    leaves = list()
    all_parents = list()
    for item in graph:
        all_parents.extend(graph[item])
    all_parents = list(set(all_parents))
    children = graph.keys()
    roots = list(set(all_parents).difference(set(children)))
    leaves = list(set(children).difference(set(all_parents)))
    return roots, leaves

def find_tool_paths_workflow(graph, start, end, path=[]):
    path = path + [end]
    if start == end:
        return [path]
    path_list = list()
    if end in graph:
        for node in graph[end]:
            if node not in path:
                new_tools_paths = find_tool_paths_workflow(graph, start, node, path)
                for tool_path in new_tools_paths:
                    path_list.append(tool_path)
    return path_list

def read_tabular_file(raw_file_path):
    """
    Read tabular file and extract workflow connections
    """
    print("Reading workflows...")
    workflows = {}
    workflow_paths_dup = ""
    workflow_parents = dict()
    workflow_paths = list()
    unique_paths = dict()
    tool_frequency = dict()
    standard_connections = dict()
    with open(raw_file_path, 'rt') as workflow_connections_file:
        workflow_connections = csv.reader(workflow_connections_file, delimiter='\t')
        for index, row in enumerate(workflow_connections):
            wf_id = str(row[0])
            in_tool = format_tool_id(row[3])
            out_tool = format_tool_id(row[6])
            if wf_id not in workflows:
                workflows[wf_id] = list()
            if out_tool and in_tool and out_tool != in_tool:
                workflows[wf_id].append((out_tool, in_tool))
            if out_tool != "":
                if out_tool not in tool_frequency:
                    tool_frequency[out_tool] = 0
                tool_frequency[out_tool] += 1
            if in_tool != "":
                if in_tool not in tool_frequency:
                    tool_frequency[in_tool] = 0
                
                tool_frequency[in_tool] += 1
    print("Reading workflows finished")
    print("Processing workflows...")
    wf_ctr = 0
    for wf_id in workflows:
        wf_ctr += 1
        workflow_parents[wf_id] = read_workflow(wf_id, workflows[wf_id])

    for wf_id in workflow_parents:
        flow_paths = list()
        parents_graph = workflow_parents[wf_id]
        roots, leaves = get_roots_leaves(parents_graph)
        for root in roots:
            for leaf in leaves:
                paths = find_tool_paths_workflow(parents_graph, root, leaf)
                # reverse the paths as they are computed from leaves to roots leaf
                paths = [tool_path for tool_path in paths]
                if len(paths) > 0:
                    flow_paths.extend(paths)
        workflow_paths.extend(flow_paths)
    print("Workflows processed: %d" % wf_ctr)

    # remove slashes from the tool ids
    wf_paths_no_slash = list()
    for path in workflow_paths:
        path_no_slash = [format_tool_id(tool_id) for tool_id in path]
        wf_paths_no_slash.append(path_no_slash)

    # collect duplicate paths
    for path in wf_paths_no_slash:
        workflow_paths_dup += ",".join(path) + "\n"
    unique_paths = list(workflow_paths_dup.split("\n"))
    unique_paths = list(filter(None, unique_paths))
    random.shuffle(unique_paths)
    paths_freq = dict()
    for path in unique_paths:
        if path not in paths_freq:
            paths_freq[path] = 0
        paths_freq[path] += 1
        
    return tool_frequency, paths_freq


wf_path = "../data/worflow-connection-20-04.tsv"
t_freq, p_freq = read_tabular_file(wf_path)
# Out:
# Reading workflows...
# Reading workflows finished
# Processing workflows...
# Workflows processed: 18659

# %%
last_tool_freq = dict()
for path in p_freq:
    last_t = path.split(",")[-1]
    if last_t not in last_tool_freq:
        last_tool_freq[last_t] = 0
    last_tool_freq[last_t] += 1

# %%
t_freq  = dict(sorted(t_freq.items(), key=lambda kv: kv[1], reverse=False))
p_freq = dict(sorted(p_freq.items(), key=lambda kv: kv[1], reverse=False))
last_tool_freq = dict(sorted(last_tool_freq.items(), key=lambda kv: kv[1], reverse=False))

# %%
def read_file(file_path):
    with open(file_path, 'r') as data_file:
        data = json.loads(data_file.read())
    return data


def create_model(model_path):
    reverse_dictionary = dict((str(v), k) for k, v in dictionary.items())
    model_weights = list()
    weight_ctr = 0
    for index, item in enumerate(trained_model.keys()):
        if "weight_" in item:
            d_key = "weight_" + str(weight_ctr)
            weights = trained_model.get(d_key).value
            model_weights.append(weights)
            weight_ctr += 1
    # set the model weights
    loaded_model.set_weights(model_weights)
    return loaded_model, dictionary, reverse_dictionary


def get_predicted_tools(base_tools, predictions, topk):
    """
    Get predicted tools. If predicted tools are less in number, combine them with published tools
    """
    precision = np.nan
    intersection = list()
    if len(base_tools) > 0:
        intersection = list(set(predictions).intersection(set(base_tools)))
        precision = len(intersection) / float(len(predictions))
    #print(base_tools)
    #print(intersection)
    #print(precision)
    #print()
    return intersection[:topk], precision


def sort_by_usage(t_list, class_weights, d_dict):
    """
    Sort predictions by usage/class weights
    """
    tool_dict = dict()
    for tool in t_list:
        t_id = d_dict[tool]
        tool_dict[tool] = class_weights[str(t_id)]
    #tool_dict = dict(sorted(tool_dict.items(), key=lambda kv: kv[1], reverse=True))
    return list(tool_dict.keys()), list(tool_dict.values())


def separate_predictions(base_tools, predictions, last_tool_name, weight_values, topk):
    """
    Get predictions from published and normal workflows
    """
    last_base_tools = list()
    predictions = predictions * weight_values
    prediction_pos = np.argsort(predictions, axis=-1)
    topk_prediction_pos = prediction_pos[-topk:]
    # get tool ids
    pred_tool_ids = [reverse_dictionary[str(tool_pos)] for tool_pos in topk_prediction_pos]
    if last_tool_name in base_tools:
        last_base_tools = base_tools[last_tool_name]
        if type(last_base_tools).__name__ == "str":
            # get published or compatible tools for the last tool in a sequence of tools
            last_base_tools = last_base_tools.split(",")
    # get predicted tools
    p_tools, precision = get_predicted_tools(last_base_tools, pred_tool_ids, topk)
    sorted_c_t, sorted_c_v = sort_by_usage(p_tools, class_weights, dictionary)
    return sorted_c_t, sorted_c_v, precision


def compute_recommendations(model, tool_sequence, labels, dictionary, reverse_dictionary, class_weights, topk=10, max_seq_len=25):
    tl_seq = tool_sequence.split(",")
    tl_seq_ids = [str(dictionary[t]) for t in tl_seq]
    last_tool_name = tl_seq[-1]
    sample = np.zeros(max_seq_len)
    weight_val = list(class_weights.values())
    weight_val = np.reshape(weight_val, (len(weight_val),))
    for idx, tool_id in enumerate(tl_seq_ids):
        sample[idx] = int(tool_id)
    sample_reshaped = np.reshape(sample, (1, max_seq_len))
    tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tl_seq_ids]
    # predict next tools for a test path
    prediction = model.predict(sample_reshaped, verbose=0)
    nw_dimension = prediction.shape[1]
    prediction = np.reshape(prediction, (nw_dimension,))
    
    half_len = int(nw_dimension / 2)
    
    pub_t, pub_v, pub_prec = separate_predictions(standard_connections, prediction[:half_len], last_tool_name, weight_val, topk)
    # get recommended tools from normal workflows
    c_t, c_v, c_prec = separate_predictions(compatible_tools, prediction[half_len:], last_tool_name, weight_val, topk)
    
    return pub_prec, c_prec

# %%
model_path = "../data/tool_recommendation_model_20_04.hdf5"
trained_model = h5py.File(model_path, 'r')
model_config = json.loads(trained_model.get('model_config').value)
dictionary = json.loads(trained_model.get('data_dictionary').value)
class_weights = json.loads(trained_model.get('class_weights').value)
standard_connections = json.loads(trained_model.get('standard_connections').value)
compatible_tools = json.loads(trained_model.get('compatible_tools').value)
loaded_model = model_from_json(model_config)
model, dictionary, reverse_dictionary = create_model(model_path)

# %%
# get tools with lowest frequency
t_lowest_freq = dict()
for t in last_tool_freq:
    if last_tool_freq[t] < 10:
        t_lowest_freq[t] = last_tool_freq[t]

# %%
last_tool_freq
# Out:
# {'mtbls520_23_seasons_rda': 1,
#  'mtbls520_08c_species_variability': 1,
#  'keras_batch_models': 1,
#  'metagene_annotator': 1,
#  'rseqc_RNA_fragment_size': 1,
#  'mtbls520_19b_seasons_unique': 1,
#  'get_sequences': 1,
#  'minfi_getM': 1,
#  'mummer_nucmer': 1,
#  'fpocket': 1,
#  'ambertools_antechamber': 1,
#  'tag_stat2': 1,
#  'ip_scale_image': 1,
#  'mlocarna': 1,
#  'cp_image_math': 1,
#  'aggregate': 1,
#  'collection_element_identifiers': 1,
#  'bed_to_bigBed': 1,
#  'ggplot2_pca': 1,
#  'mtbls520_08d_concentration': 1,
#  'ip_histogram_equalization': 1,
#  'rseqc_clipping_profile': 1,
#  'cp_relate_objects': 1,
#  'gops_basecoverage_1': 1,
#  'Nucleosome': 1,
#  'gemini_de_novo': 1,
#  'vcfaddinfo': 1,
#  'mtbls520_09_species_venn': 1,
#  'pileup_interval': 1,
#  'mothur_phylotype': 1,
#  'vsearch_sorting': 1,
#  'tp_uniq_tool': 1,
#  'interactive_tool_phinch': 1,
#  'p_clip_peaks': 1,
#  'mtbls520_08b_species_unique': 1,
#  'scater_plot_tsne': 1,
#  'deeptools_alignmentsieve': 1,
#  'ctb_filter': 1,
#  'ip_binary_to_labelimage': 1,
#  'picard_SortSam': 1,
#  'hgv_linkToGProfile': 1,
#  'peakcalling_sicer': 1,
#  'velvetg_jgi': 1,
#  'mothur_align_seqs': 1,
#  'gemini_comp_hets': 1,
#  'cshl_fasta_nucleotides_changer': 1,
#  'ConsensusID': 1,
#  'CONVERTER_gz_to_uncompressed': 1,
#  'keras_train_and_eval': 1,
#  'diffbind-embl': 1,
#  'mtbls520_19e_seasons_features': 1,
#  'express': 1,
#  'get_feature_info': 1,
#  'bedtools_multiintersectbed': 1,
#  'deeptools_bigwigCompare': 1,
#  'maxquant': 1,
#  'climate_stripes': 1,
#  'idba_hybrid': 1,
#  'signalp3': 1,
#  'mtbls520_08a_species_shannon': 1,
#  'lastz_wrapper_2': 1,
#  'interactive_tool_fairdom_send': 1,
#  'maldi_quant_preprocessing': 1,
#  'cd_hit_est': 1,
#  '_ensembl_gtf2gene_list': 1,
#  'bedtools_groupbybed': 1,
#  'convert_bc_to_binary_RY.py': 1,
#  'gemini_interactions': 1,
#  '__EXTRACT_DATASET__': 1,
#  'Remove_ending': 1,
#  'samtools_markdup': 1,
#  'xpath': 1,
#  'htseq-count': 1,
#  'blastxml_to_tabular': 1,
#  'subtract_query1': 1,
#  'rseqc_insertion_profile': 1,
#  'mothur_make_group': 1,
#  'rbc_mirdeep2_mapper': 1,
#  'modencode_peakcalling_spp': 1,
#  'samtools_merge': 1,
#  'minfi_methcpg': 1,
#  'ctb_chemfp_mol2fps': 1,
#  'mtbls520_18_phylogeny': 1,
#  'microsat_pal_finder': 1,
#  'flexbar_no_split': 1,
#  'raceid_clustering': 1,
#  'xchem_transfs_scoring': 1,
#  'picard_NormalizeFasta': 1,
#  'CONVERTER_bed_to_bgzip_0': 1,
#  'sailfish': 1,
#  'scanpy_compute_graph': 1,
#  'genomespace_exporter': 1,
#  'macs2_bdgcmp': 1,
#  'kallisto_pseudo': 1,
#  'snp_sites': 1,
#  'rgPicFixMate': 1,
#  'fastq_stats': 1,
#  'snpSift_dbnsfp_generic': 1,
#  'Batch_correction': 1,
#  'gmx_editconf': 1,
#  'ivar_consensus': 1,
#  'gemini_pathways': 1,
#  'correctGCBias': 1,
#  'enhanced_bowtie_wrapper': 1,
#  'shyft_longitudes': 1,
#  'fastp': 1,
#  'mothur_make_contigs': 1,
#  'SequenceCoverageCalculator': 1,
#  'metaspades': 1,
#  'seqtk_mergefa': 1,
#  'mummer_mummer': 1,
#  'mtbls520_10_species_varpart': 1,
#  'gemini_stats': 1,
#  'gemini_windower': 1,
#  'cufflinks_prok': 1,
#  'vsearch_dereplication': 1,
#  'vcfselectsamples': 1,
#  'sklearn_feature_selection': 1,
#  'scater_plot_exprs_freq': 1,
#  'bedtools_slopbed': 1,
#  'FROGS_affiliations_stat': 1,
#  'picard_CleanSam': 1,
#  'progressivemauve': 1,
#  'hicexplorer_hicplotviewpoint': 1,
#  'extract_aln_ends.py': 1,
#  'hicexplorer_hicmergematrixbins': 1,
#  'secure_hash_message_digest': 1,
#  'mummer_mummerplot': 1,
#  'tabular_to_csv': 1,
#  'cd_hit_protein': 1,
#  'mtbls520_12_species_marchantia': 1,
#  'IDMassAccuracy': 1,
#  'mtbls520_08e_species_features': 1,
#  'minfi_dmp': 1,
#  'repeatexplorer2': 1,
#  'OpenSwathWorkflow': 1,
#  'gatk2_variant_filtration': 1,
#  'tp_sort_rows': 1,
#  'igvtools_count': 1,
#  'bamSplit': 1,
#  'numeric_clustering': 1,
#  'tarean_exp': 1,
#  'smf_utils_find-boxes': 1,
#  'mtbls520_19d_seasons_concentration': 1,
#  'sklearn_clf_metrics': 1,
#  'cp_export_to_spreadsheet': 1,
#  'eggnog_mapper': 1,
#  'gd_calc_freq': 1,
#  'metaphlan2krona': 1,
#  'ucsc-twobittofa': 1,
#  'cp_convert_objects_to_image': 1,
#  'methtools_tiling': 1,
#  'FeatureFinderMultiplex': 1,
#  'mothur_summary_qual': 1,
#  'bamtools_split': 1,
#  'IDPosteriorErrorProbability': 1,
#  'rseqc_mismatch_profile': 1,
#  'ip_2d_split_binaryimage_by_watershed': 1,
#  'Determine_BC': 1,
#  'exonerate': 1,
#  'ctb_ob_genProp': 1,
#  'percolator_input_converters': 1,
#  'stacks_refmap': 1,
#  'padel': 1,
#  'metaphlan2_hutlab': 1,
#  'FeatureLinkerUnlabeled': 1,
#  'Fetch Taxonomic Ranks': 1,
#  'bed_to_bigwig': 1,
#  'countKeggs': 1,
#  'cast': 1,
#  'vsearch_search': 1,
#  'param_value_from_file': 1,
#  'mtbls520_19a_seasons_shannon': 1,
#  'bgchem_fragment_merger': 1,
#  'CONVERTER_fasta_to_tabular': 1,
#  'EMBOSS: wordcount109': 1,
#  'CONVERTER_bed_to_gff_0': 1,
#  'extract_bcs.py': 1,
#  'TargetedFileConverter': 1,
#  'sRNAPipe': 1,
#  'Kraken2Tax': 1,
#  'mtbls520_16_ecology_rda': 1,
#  'minfi_getanno': 1,
#  'flye': 1,
#  'sm_mirdeep2core_without_Randfold': 1,
#  'AnnovarShed': 1,
#  'sam2interval': 1,
#  'pureclip': 1,
#  'cshl_easyjoin': 1,
#  'bg_diamond': 1,
#  'EMBOSS: water107': 1,
#  'gemini_burden': 1,
#  'trnascan': 1,
#  'vsearch_clustering': 1,
#  'dada2_filterAndTrim': 1,
#  'abims_CAMERA_combinexsAnnos': 1,
#  'gdal_gdalinfo': 1,
#  'deeptools_plot_enrichment': 1,
#  'miranda': 1,
#  'gtf2bedgraph': 1,
#  'w4mclassfilter': 1,
#  'MapStatistics': 1,
#  'minfi_getsnp': 1,
#  'cshl_princeton_fastx_barcode_splitter': 1,
#  'ip_filter_standard': 1,
#  'sample_seqs': 1,
#  'EMBOSS: textsearch98': 1,
#  'sequence_content_trimmer': 1,
#  'hmmer_hmmscan': 1,
#  'diffexp': 1,
#  'Kneeplot': 1,
#  'ncbi_tblastn_wrapper': 1,
#  'maker_map_ids': 1,
#  'stoceps_glm': 1,
#  'react_cal_pipeline': 1,
#  'hicexplorer_hicsummatrices': 1,
#  'stacks2_populations': 1,
#  'ProteinResolver': 1,
#  'gff_to_sequence': 1,
#  'mimodd_info': 1,
#  'miniasm': 1,
#  'vcfbreakcreatemulti': 1,
#  'picard_MarkDuplicatesWithMateCigar': 1,
#  'abims_xcms_summary': 1,
#  'ctb_osra': 1,
#  'fastq_paired_end_splitter': 1,
#  'reactome_analysis': 1,
#  'Krona': 1,
#  'fastq_filter': 1,
#  'sklearn_train_test_eval': 1,
#  'Jvenn': 1,
#  'vigiechiro_bilanenrichirp': 1,
#  'gops_subtract_1': 1,
#  'rdock_rbcavity': 1,
#  'rmcontamination': 1,
#  'dt_profiler': 1,
#  'nonpareil': 1,
#  'pyprophet_export': 1,
#  'mass_spectrometry_imaging_segmentations': 1,
#  'sceasy_convert': 1,
#  'stacks_genotypes': 1,
#  '_dropletBarcodePlot': 1,
#  'gatk4_mutect2': 1,
#  'ip_imageinfo': 1,
#  'openbabel_compound_convert': 1,
#  'minfi_mset': 1,
#  'ambertools_acpype': 1,
#  'vg_deconstruct': 1,
#  'minfi_ppfun': 1,
#  'psy_maps': 1,
#  'minfi_qc': 1,
#  'ctb_obgrep': 1,
#  'fgsea': 1,
#  'dropletutils': 1,
#  'mummer_dnadiff': 1,
#  'hyphy_gard': 1,
#  'EMBOSS: revseq82': 1,
#  'deeptools_bigwig_compare': 1,
#  'qiime_count_seqs': 1,
#  'vigiechiro_bilanenrichipf': 1,
#  'vegan_rarefaction': 2,
#  'mcClust': 2,
#  'cshl_fastx_trimmer': 2,
#  'picard_DownsampleSam': 2,
#  'sklearn_stacking_ensemble_models': 2,
#  '16Sclassifier': 2,
#  'seurat_export_cellbrowser': 2,
#  'bwa': 2,
#  'varscan_copynumber': 2,
#  'pick_open_reference_otus': 2,
#  'mothur_collect_single': 2,
#  'picard_FixMateInformation': 2,
#  'extract': 2,
#  'ggplot2_heatmap': 2,
#  'abims_xcms_fillPeaks': 2,
#  'ete_homology_classifier': 2,
#  'gd_raxml': 2,
#  'w4mclstrpeakpics': 2,
#  'iframe': 2,
#  'vcfannotate': 2,
#  'minfi_dmr': 2,
#  'lofreq_call': 2,
#  'mothur_remove_seqs': 2,
#  'bedtools_subtractbed': 2,
#  'mmpbsa_mmgbsa': 2,
#  'vcf2pgSnp': 2,
#  'map_peptides_to_bed': 2,
#  'ncbi_makeblastdb': 2,
#  'megahit_contig2fastg': 2,
#  'ctb_rdkit_descriptors': 2,
#  'mothur_merge_files': 2,
#  'ip_2d_filter_segmentation_by_features': 2,
#  'w4mcorcov': 2,
#  'bg_statistical_hypothesis_testing': 2,
#  'heinz': 2,
#  'vsearch_chimera_detection': 2,
#  'schicexplorer_schicplotconsensusmatrices': 2,
#  'mothur_chimera_vsearch': 2,
#  'biom_convert': 2,
#  'EMBOSS: fuzzpro38': 2,
#  'filter_tabular': 2,
#  'tbvcfreport': 2,
#  'modencode_peakcalling_macs2': 2,
#  'find_in_reference': 2,
#  'graphicsmagick_image_montage': 2,
#  'schicexplorer_schicplotclusterprofiles': 2,
#  'rgPicardMarkDups': 2,
#  'vegan_diversity': 2,
#  'rdpmulticlassifier': 2,
#  'scmap_scmap_cluster': 2,
#  'iuc_deseq2': 2,
#  'heatmapper': 2,
#  'dada2_dada': 2,
#  'md_converter': 2,
#  'bg_sortmerna': 2,
#  'maker': 2,
#  'custom_pro_db': 2,
#  'picard_ValidateSamFile': 2,
#  'clusterprofiler_go': 2,
#  'regexColumn1': 2,
#  'viennarna_rnafold': 2,
#  'mothur_chimera_uchime': 2,
#  'FidoAdapter': 2,
#  'minimap2': 2,
#  '__MERGE_COLLECTION__': 2,
#  'idpquery': 2,
#  'rseqc_read_duplication': 2,
#  'samtools_slice_bam': 2,
#  'snpsift_vartype': 2,
#  'basil': 2,
#  'picard_EstimateLibraryComplexity': 2,
#  'sqlite_to_tabular': 2,
#  'picard_AddOrReplaceReadGroups': 2,
#  'gene2exon1': 2,
#  'seurat': 2,
#  'kraken-mpa-report': 2,
#  'checkFormat': 2,
#  'pieplots_macs': 2,
#  'gatk_indel_realigner': 2,
#  'FastTree': 2,
#  'sam_pileup': 2,
#  'gmx_setup': 2,
#  'trinity_abundance_estimates_to_matrix': 2,
#  'predict_pipeline': 2,
#  'scmap_scmap_cell': 2,
#  'qiime_align_seqs': 2,
#  'bcftools_stats': 2,
#  '__FILTER_FAILED_DATASETS__': 2,
#  'openbabel_svg_depiction': 2,
#  'blockclust': 2,
#  'gatk2_variant_select': 2,
#  'minfi_getbeta': 2,
#  'cshl_awk_replace_in_column': 2,
#  'raceid_inspecttrajectory': 2,
#  'openms_id_mapper': 2,
#  'MultiplexResolver': 2,
#  'fastq_trimmer': 2,
#  'methtools_calling': 2,
#  'cshl_fastq_to_fasta': 2,
#  'bedtools_genomecoveragebed_histogram': 2,
#  'rseqc_junction_annotation': 2,
#  'bismark_bowtie': 2,
#  'shovill': 2,
#  'flashlfq': 2,
#  'vcfgenotypes': 2,
#  'rna_starsolo': 2,
#  'gatk2_realigner_target_creator': 2,
#  'deeptools_bam_pe_fragmentsize': 2,
#  'CONVERTER_bedgraph_to_bigwig': 2,
#  'EMBOSS: geecee41': 2,
#  'seq_composition': 2,
#  'mothur_unique_seqs': 2,
#  'gdal_ogr2ogr': 2,
#  'kraken-translate': 2,
#  'heinz_scoring': 2,
#  'sklearn_searchcv': 2,
#  'blockbuster': 2,
#  'gatk_unified_genotyper': 2,
#  'cummerbund_to_cuffdiff': 2,
#  'rdock_rbdock': 2,
#  'smf_utils_filter-by-energy': 2,
#  'ia_coordinates_of_roi': 2,
#  'filtlong': 2,
#  'Psortb': 2,
#  'openbabel_remDuplicates': 2,
#  'velvetoptimiser': 2,
#  'sklearn_model_validation': 2,
#  'iedb_api': 2,
#  'sccaf_regress_out': 2,
#  'cluter_profiler': 2,
#  'nspdk_sparse': 2,
#  'goenrichment': 2,
#  'xchem_pose_scoring': 2,
#  'plotly_parallel_coordinates_plot': 2,
#  'sccaf_asses_merger': 2,
#  'deeptools_correct_gc_bias': 2,
#  'picard_ReorderSam': 2,
#  'decoyfasta': 2,
#  'metaquantome_viz': 2,
#  'bg_protein_properties': 2,
#  'cat_bins': 2,
#  'nn_classifier': 2,
#  'snpfinder': 2,
#  'resistome_analyzer': 2,
#  'infernal_cmstat': 2,
#  'hyphy_absrel': 2,
#  'fastq_paired_end_interlacer': 2,
#  'qiime_core_diversity': 2,
#  'sixgill_build': 3,
#  'bcftools_norm': 3,
#  'bedtools_bed12tobed6': 3,
#  'cshl_multijoin': 3,
#  'rseqc_junction_saturation': 3,
#  'sam_bw_filter': 3,
#  'rseqc_FPKM_count': 3,
#  'trinity_align_and_estimate_abundance': 3,
#  'get_flanks1': 3,
#  'cshl_fastx_nucleotides_distribution': 3,
#  'smooth_running_window': 3,
#  'scater_plot_dist_scatter': 3,
#  'samtools_calmd': 3,
#  'cshl_find_and_replace': 3,
#  'mass_spectrometry_imaging_filtering': 3,
#  'dexseq_annotate': 3,
#  'scater_plot_pca': 3,
#  'fastq_groomer': 3,
#  'search_gui': 3,
#  'uniprot': 3,
#  'table_annovar': 3,
#  'cat_summarise': 3,
#  'velvetg': 3,
#  'raceid_trajectory': 3,
#  'gatk2_base_recalibrator': 3,
#  'bcftools_plugin_counts': 3,
#  'rgweblogo3': 3,
#  'merge_pcr_duplicates.py': 3,
#  'mimodd_map': 3,
#  'picard_BamIndexStats': 3,
#  'ip_projective_transformation_points': 3,
#  'tophat_fusion_post': 3,
#  'vcfbedintersect': 3,
#  'bcftools_view': 3,
#  'gmx_trj': 3,
#  'peakcalling_macs': 3,
#  'gffread': 3,
#  'fasterq_dump': 3,
#  'EMBOSS: getorf42': 3,
#  'picard_MergeSamFiles': 3,
#  'ip_2d_feature_extraction': 3,
#  'circgraph': 3,
#  'cardinal_data_exporter': 3,
#  'bwa_wrapper': 3,
#  'vcftools_slice': 3,
#  'bam_to_bigwig': 3,
#  'umi_tools_group': 3,
#  'ctb_remove_protonation_state': 3,
#  'jcvi_gff_stats': 3,
#  'mass_spectrometry_imaging_mzplots': 3,
#  'gatk_analyze_covariates': 3,
#  'bismark_pretty_report': 3,
#  'segemehl': 3,
#  'vcftools_isec': 3,
#  'picard_CollectWgsMetrics': 3,
#  'deeptools_compute_matrix_operations': 3,
#  'mass_spectrometry_imaging_classification': 3,
#  'EMBOSS: tranalign100': 3,
#  'tp_split_on_column': 3,
#  'bedtools_sortbed': 3,
#  'cutadapt': 3,
#  'snpSift_int': 3,
#  'snpeff_to_peptides': 3,
#  'unipept': 3,
#  'cor2': 3,
#  'snippy_core': 3,
#  'umi_tools_extract': 3,
#  'gtftobed12': 3,
#  'trimmer': 3,
#  'Datamash': 3,
#  'trinity_samples_qccheck': 3,
#  'canu': 3,
#  'aggregate_scores_in_intervals2': 3,
#  'trinotate': 3,
#  'lfq_protein_quant': 3,
#  'metfrag-cli-batch-multiple': 3,
#  'gmx_restraints': 3,
#  'medaka_consensus': 3,
#  'crosscontamination_barcode_filter': 3,
#  'deeptools_computeGCBias': 3,
#  'gemini_annotate': 3,
#  'ococo': 3,
#  'ip_viz_overlay_moving_and_fixed_image': 3,
#  'cmv': 3,
#  'megablast_wrapper': 4,
#  'bamtools': 4,
#  'naive_variant_caller': 4,
#  'tabular_to_fastq': 4,
#  'split_file_to_collection': 4,
#  'gmx_em': 4,
#  'translate_bed_sequences': 4,
#  'kallisto_quant': 4,
#  'gatk_count_covariates': 4,
#  'megablast_xml_parser': 4,
#  'abims_CAMERA_annotateDiffreport': 4,
#  'bedtools_bedtobam': 4,
#  'hicexplorer_hicpca': 4,
#  'maxbin2': 4,
#  'bundle_collection': 4,
#  '__FLATTEN__': 4,
#  'ip_count_objects': 4,
#  'sklearn_ensemble': 4,
#  'datamash_transpose': 4,
#  'cshl_awk_tool': 4,
#  'cardinal_preprocessing': 4,
#  'xcms_merge': 4,
#  'deeptools_profiler': 4,
#  'qiime_assign_taxonomy': 4,
#  'bedtools_genomecoveragebed_bedgraph': 4,
#  'proteomics_search_protein_prophet_1': 4,
#  'regionalgam_autocor_acf': 4,
#  'MetaProSIP': 4,
#  'bcftools_call': 4,
#  'samtools_bedcov': 4,
#  'raceid_inspectclusters': 4,
#  'ctb_shapeit': 4,
#  'paralyzer': 4,
#  'scanpy_run_umap': 4,
#  'circos': 4,
#  'GeMoMa_Annotation_Filter': 4,
#  'snpSift_geneSets': 4,
#  'qualimap_rnaseq': 4,
#  'rarefaction': 4,
#  'cshl_fastq_quality_boxplot': 4,
#  'deseq2_single': 4,
#  'bamCoverage_deepTools': 4,
#  'seq_filter_by_mapping': 4,
#  'ctb_compound_convert': 4,
#  'regionalgam_glmmpql': 4,
#  'allele_counts_1': 4,
#  'seurat_dim_plot': 4,
#  'gops_join_1': 4,
#  'gmx_solvate': 4,
#  '__BUILD_LIST__': 4,
#  '__TAG_FROM_FILE__': 4,
#  'tmhmm2': 4,
#  'fastq_to_tabular': 4,
#  'hicexplorer_hicfindtads': 4,
#  'mass_spectrometry_imaging_combine': 4,
#  'tb_variant_filter': 4,
#  'bedtools_bamtofastq': 4,
#  'deeptools_computeMatrix': 4,
#  'stoceps_glm_group': 4,
#  'diffbind': 4,
#  'rbc_rnacode': 4,
#  'bamleftalign': 4,
#  'mdanalysis_cosine_analysis': 4,
#  'bio3d_pca_visualize': 4,
#  'vmd_hbonds': 4,
#  'flexbar': 4,
#  'seqtk_subseq': 4,
#  'viz_overlay_moving_and_fixed_image': 4,
#  'metaphlan_hclust_heatmap': 5,
#  'umi_tools_dedup': 5,
#  'ivar_variants': 5,
#  'cshl_fastq_quality_filter': 5,
#  'quality_metrics': 5,
#  'ChangeCase': 5,
#  'bam2wig': 5,
#  'roary': 5,
#  'massbank_ws_searchspectrum': 5,
#  'metilene': 5,
#  'bedtools_multicovtbed': 5,
#  'bedtools_coveragebed': 5,
#  'picard_SamToFastq': 5,
#  'cp_cellprofiler': 5,
#  'bg_column_arrange_by_header': 5,
#  'tp_tac': 5,
#  'macs2_predictd': 5,
#  'sdf_to_tab': 5,
#  'samtools_depth': 5,
#  'limma_voom': 5,
#  'addName': 5,
#  'dexseq_count': 5,
#  'aragorn_trna': 5,
#  'PeptideIndexer': 5,
#  'trinity_run_de_analysis': 5,
#  'mothur_screen_seqs': 5,
#  'vcftools_merge': 5,
#  'CONVERTER_bed_gff_or_vcf_to_bigwig_0': 5,
#  'rbc_mirdeep2': 5,
#  'cuffquant': 5,
#  'bismark_methylation_extractor': 5,
#  'heinz_visualization': 5,
#  'annotateMyIDs': 5,
#  'trinity_contig_exn50_statistic': 5,
#  'methtools_destrand': 5,
#  'IDScoreSwitcher': 5,
#  'IDFilter': 5,
#  'gops_concat_1': 5,
#  'mergeCols1': 5,
#  'stacks_populations': 5,
#  'picard_CollectRnaSeqMetrics': 5,
#  'CONVERTER_Bam_Bai_0': 5,
#  'rbc_mirdeep2_quantifier': 5,
#  'viennarna_rnaalifold': 5,
#  'regex1': 5,
#  'plotly_regression_performance_plots': 5,
#  'mimodd_vcf_filter': 5,
#  'augustus': 5,
#  'table_compute': 5,
#  'varscan_mpileup': 6,
#  'cuffnorm': 6,
#  'racon': 6,
#  'gatk2_print_reads': 6,
#  'ctb_subsearch': 6,
#  'xcms_plot_chromatogram': 6,
#  'muscle': 6,
#  'mimodd_varreport': 6,
#  'gatk2_unified_genotyper': 6,
#  'stringtie_merge': 6,
#  'bismark_bowtie2': 6,
#  'bowtie_wrapper': 6,
#  'samtools_view': 6,
#  'varscan_somatic': 6,
#  'build_ucsc_custom_track_1': 6,
#  'PicardASMetrics': 6,
#  'vcfvcfintersect': 6,
#  'snippy': 6,
#  'PicardInsertSize': 6,
#  'cshl_sort_header': 6,
#  'EMBOSS: transeq101': 6,
#  'regionalgam_plot_trend': 6,
#  'CONVERTER_gff_to_bed_0': 6,
#  'rseqc_geneBody_coverage': 6,
#  'cshl_word_list_grep': 6,
#  'cardinal_combine': 6,
#  'IDMapper': 6,
#  'sucos_max_score': 6,
#  'vcf_filter': 6,
#  'raceid_main': 6,
#  'venn_list': 6,
#  'cuffmerge': 6,
#  'filter_by_fasta_ids': 6,
#  'blast2go': 6,
#  'cloudmap_variant_discovery_mapping': 6,
#  'humann2': 6,
#  'hmmer_jackhmmer': 6,
#  'gemini_inheritance': 6,
#  'umi_tools_count': 6,
#  'gmx_npt': 6,
#  'trinity_define_clusters_by_cutting_tree': 6,
#  'ctb_chemfp_butina_clustering': 6,
#  'cshl_fasta_formatter': 6,
#  'humann2_unpack_pathways': 6,
#  'lofreq_filter': 7,
#  'QCCalculator': 7,
#  'freebayes_wrapper': 7,
#  'salmon': 7,
#  'fasta_merge_files_and_filter_unique_sequences': 7,
#  'vcffixup': 7,
#  'clustalw': 7,
#  'bio3d_pca': 7,
#  'gatk2_depth_of_coverage': 7,
#  'DecoyDatabase': 7,
#  'cshl_fastx_reverse_complement': 7,
#  '__APPLY_RULES__': 7,
#  'bio3d_rmsd': 7,
#  'rseqc_bam2wig': 7,
#  'trinity': 7,
#  'rnaz': 7,
#  'scanpy_run_tsne': 7,
#  'bedtools_bamtobed': 7,
#  'ctb_spectrophore_search': 7,
#  'docking': 7,
#  'bio3d_rmsf': 7,
#  'maldi_quant_peak_detection': 7,
#  'hicexplorer_hicbuildmatrix': 7,
#  'qiime_pick_closed_reference_otus': 7,
#  'pilon': 7,
#  'Extract_features1': 7,
#  'valet': 7,
#  'deeptools_bamFingerprint': 7,
#  'tp_find_and_replace': 8,
#  'samtool_filter2': 8,
#  'snpSift_filter': 8,
#  'snpSift_annotate': 8,
#  'deeptools_bamCorrelate': 8,
#  'ctb_np-likeness-calculator': 8,
#  'bedtools_intersectbed_bam': 8,
#  'trimmomatic': 8,
#  'ctb_alignit': 8,
#  'fasta_compute_length': 8,
#  'IDMerger': 8,
#  't2t_report': 8,
#  'deeptools_bam_compare': 8,
#  'transdecoder': 8,
#  'openms_protein_quantifier': 8,
#  'deeptools_plot_coverage': 8,
#  'FalseDiscoveryRate': 8,
#  'ctb_rdkit_describtors': 8,
#  'PlasFlow': 8,
#  'random_lines1': 8,
#  'ip_overlay_segmentation': 8,
#  'egsea': 8,
#  'bwa_mem': 8,
#  'ctb_stripit': 8,
#  'cardinal_spectra_plots': 8,
#  'cshl_cut_tool': 8,
#  '__ZIP_COLLECTION__': 9,
#  'deeptools_compute_matrix': 9,
#  'regex_replace': 9,
#  'ctb_silicos_qed': 9,
#  'draw_circos': 9,
#  'unicycler': 9,
#  'mothur_filter_seqs': 9,
#  'fraggenescan': 9,
#  'fastq_to_fasta_python': 9,
#  'gffcompare': 9,
#  'samtools_fastx': 9,
#  'vcfallelicprimitives': 9,
#  'rseqc_inner_distance': 9,
#  'deg_annotate': 9,
#  'tophat2': 9,
#  'CONVERTER_interval_to_bedstrict_0': 9,
#  'pipmir': 9,
#  'rseqc_read_distribution': 9,
#  'scanpy_find_markers': 9,
#  'cardinal_segmentations': 9,
#  'cshl_uniq_tool': 9,
#  'openbabel_filter': 9,
#  'gmx_sim': 9,
#  'glimmer_knowlegde-based': 9}

# %%
topk = 1
complete_p_prec = list()
complete_c_prec = list()

freq = list()
print("Number of tool sequences: %d" % len(p_freq))
ctr = 0
for t_seq in p_freq:
    last_tool = t_seq.split(",")[-1]
    if last_tool in t_lowest_freq.keys():
        p_prec, c_prec = compute_recommendations(model, t_seq, "", dictionary, reverse_dictionary, class_weights, topk)
        complete_p_prec.append(p_prec)
        complete_c_prec.append(c_prec)
        freq.append(p_freq[t_seq])
        ctr+= 1

for t_seq in t_lowest_freq:
    p_prec, c_prec = compute_recommendations(model, t_seq, "", dictionary, reverse_dictionary, class_weights, topk)
    complete_p_prec.append(p_prec)
    complete_c_prec.append(c_prec)
    freq.append(t_lowest_freq[t_seq])
    ctr+= 1
    
print("Published precision: %s" % str(np.nanmean(complete_p_prec)))
print("Normal precision: %s" % str(np.nanmean(complete_c_prec)))
print("Number of paths used : %s" % ctr)
print("Mean frequency: %s" % str(np.mean(freq)))
# Out:
# Number of tool sequences: 198459
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-161-459ee921e2f7> in <module>
#      16
#      17 for t_seq in t_lowest_freq:
# ---> 18     p_prec, c_prec = compute_recommendations(model, t_seq, "", dictionary, reverse_dictionary, class_weights, topk)
#      19     complete_p_prec.append(p_prec)
#      20     complete_c_prec.append(c_prec)
#
# <ipython-input-119-32812f2c9012> in compute_recommendations(model, tool_sequence, labels, dictionary, reverse_dictionary, class_weights, topk, max_seq_len)
#      81     tool_sequence_names = [reverse_dictionary[str(tool_pos)] for tool_pos in tl_seq_ids]
#      82     # predict next tools for a test path
# ---> 83     prediction = model.predict(sample_reshaped, verbose=0)
#      84     nw_dimension = prediction.shape[1]
#      85     prediction = np.reshape(prediction, (nw_dimension,))
#
# ~/miniconda3/envs/tool_prediction_gru_wc/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# ~/miniconda3/envs/tool_prediction_gru_wc/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# ~/miniconda3/envs/tool_prediction_gru_wc/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3074
#    3075     fetched = self._callable_fn(*array_vals,
# -> 3076                                 run_metadata=self.run_metadata)
#    3077     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3078     return nest.pack_sequence_as(self._outputs_structure,
#
# ~/miniconda3/envs/tool_prediction_gru_wc/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
complete_p_prec
# Out:
# [nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  0.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  0.0,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  1.0,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  1.0,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  0.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  0.0,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]
