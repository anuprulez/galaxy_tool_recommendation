# %%
import csv
import random


def format_tool_id(tool_link):
    """
    Extract tool id from tool link
    """
    tool_id_split = tool_link.split("/")
    tool_id = tool_id_split[-2] if len(tool_id_split) > 1 else tool_link
    return tool_id

def read_workflow(wf_id, workflow_rows):
    """
    Read all connections for a workflow
    """
    tool_parents = dict()
    for connection in workflow_rows:
        in_tool = connection[0]
        out_tool = connection[1]
        if out_tool not in tool_parents:
            tool_parents[out_tool] = list()
        if in_tool not in tool_parents[out_tool]:
            tool_parents[out_tool].append(in_tool)
    return tool_parents

def get_roots_leaves(graph):
    roots = list()
    leaves = list()
    all_parents = list()
    for item in graph:
        all_parents.extend(graph[item])
    all_parents = list(set(all_parents))
    children = graph.keys()
    roots = list(set(all_parents).difference(set(children)))
    leaves = list(set(children).difference(set(all_parents)))
    return roots, leaves

def find_tool_paths_workflow(graph, start, end, path=[]):
    path = path + [end]
    if start == end:
        return [path]
    path_list = list()
    if end in graph:
        for node in graph[end]:
            if node not in path:
                new_tools_paths = find_tool_paths_workflow(graph, start, node, path)
                for tool_path in new_tools_paths:
                    path_list.append(tool_path)
    return path_list

def read_tabular_file(raw_file_path):
    """
    Read tabular file and extract workflow connections
    """
    print("Reading workflows...")
    workflows = {}
    workflow_paths_dup = ""
    workflow_parents = dict()
    workflow_paths = list()
    unique_paths = dict()
    tool_frequency = dict()
    standard_connections = dict()
    with open(raw_file_path, 'rt') as workflow_connections_file:
        workflow_connections = csv.reader(workflow_connections_file, delimiter='\t')
        for index, row in enumerate(workflow_connections):
            wf_id = str(row[0])
            in_tool = format_tool_id(row[3])
            out_tool = format_tool_id(row[6])
            if wf_id not in workflows:
                workflows[wf_id] = list()
            if out_tool and in_tool and out_tool != in_tool:
                workflows[wf_id].append((out_tool, in_tool))
            if out_tool != "":
                if out_tool not in tool_frequency:
                    tool_frequency[out_tool] = 0
                tool_frequency[out_tool] += 1
            if in_tool != "":
                if in_tool not in tool_frequency:
                    tool_frequency[in_tool] = 0
                
                tool_frequency[in_tool] += 1
    print("Reading workflows finished")
    print("Processing workflows...")
    wf_ctr = 0
    for wf_id in workflows:
        wf_ctr += 1
        workflow_parents[wf_id] = read_workflow(wf_id, workflows[wf_id])

    for wf_id in workflow_parents:
        flow_paths = list()
        parents_graph = workflow_parents[wf_id]
        roots, leaves = get_roots_leaves(parents_graph)
        for root in roots:
            for leaf in leaves:
                paths = find_tool_paths_workflow(parents_graph, root, leaf)
                # reverse the paths as they are computed from leaves to roots leaf
                paths = [tool_path for tool_path in paths]
                if len(paths) > 0:
                    flow_paths.extend(paths)
        workflow_paths.extend(flow_paths)
    print("Workflows processed: %d" % wf_ctr)

    # remove slashes from the tool ids
    wf_paths_no_slash = list()
    for path in workflow_paths:
        path_no_slash = [format_tool_id(tool_id) for tool_id in path]
        wf_paths_no_slash.append(path_no_slash)

    # collect duplicate paths
    for path in wf_paths_no_slash:
        workflow_paths_dup += ",".join(path) + "\n"
    unique_paths = list(workflow_paths_dup.split("\n"))
    unique_paths = list(filter(None, unique_paths))
    paths_freq = dict()
    for path in unique_paths:
        if path not in paths_freq:
            paths_freq[path] = 0
        paths_freq[path] += 1
        
    return tool_frequency, paths_freq


wf_path = "../data/worflow-connection-20-04.tsv"
t_freq, p_freq = read_tabular_file(wf_path)

t_freq  = dict(sorted(t_freq.items(), key=lambda kv: kv[1], reverse=False))
p_freq = dict(sorted(p_freq.items(), key=lambda kv: kv[1], reverse=False))
# Out:
# Reading workflows...
# Reading workflows finished
# Processing workflows...
# Workflows processed: 18659

# %%
t_freq
# Out:
# {'cshl_awk_tool1': 1,
#  'ncbi_tblastx_wrapper': 1,
#  'msconvert3': 1,
#  'bed_to_bigBed': 1,
#  'gemini_windower': 1,
#  'createInterval': 1,
#  'EMBOSS: pepstats71': 1,
#  'numeric_clustering': 1,
#  'cardinal_qc': 1,
#  'bed_to_bigwig': 1,
#  'igvtools_count': 1,
#  'GeMoMa_Annotation_Filter': 1,
#  'FROGS_affiliations_stat': 1,
#  'get_feature_info': 1,
#  'mothur_phylotype': 1,
#  'minfi_getanno': 1,
#  'minfi_methcpg': 1,
#  'minfi_getM': 1,
#  'cufflinks_prok': 1,
#  'snpSift_dbnsfp_generic': 1,
#  'velvetg_jgi': 1,
#  'FeatureLinkerUnlabeled': 1,
#  'packmol': 1,
#  'gops_basecoverage_1': 1,
#  'ggplot2_heatmap': 1,
#  'mcClust': 1,
#  'FastTree': 1,
#  'tag_stat2': 1,
#  '16Sclassifier': 1,
#  'kpca1': 1,
#  'scpipe': 1,
#  'dgidb_annotator': 1,
#  'enhanced_bowtie_wrapper': 1,
#  'vsearch_chimera_detection': 1,
#  'sortmerna_wrapper': 1,
#  'AnnovarShed': 1,
#  'qiime_alpha_diversity': 1,
#  'align_back_trans': 1,
#  'mtbls520_18_phylogeny': 1,
#  'mtbls520_23_seasons_rda': 1,
#  'mtbls520_19e_seasons_features': 1,
#  'mtbls520_19d_seasons_concentration': 1,
#  'mtbls520_08c_species_variability': 1,
#  'mtbls520_19b_seasons_unique': 1,
#  'mtbls520_19a_seasons_shannon': 1,
#  'mtbls520_12_species_marchantia': 1,
#  'mtbls520_16_ecology_rda': 1,
#  'mtbls520_10_species_varpart': 1,
#  'mtbls520_09_species_venn': 1,
#  'mtbls520_08e_species_features': 1,
#  'mtbls520_08d_concentration': 1,
#  'mtbls520_08b_species_unique': 1,
#  'mtbls520_08a_species_shannon': 1,
#  'EMBOSS: dan19': 1,
#  'eggnog_mapper': 1,
#  'shyft_longitudes': 1,
#  'rseqc_mismatch_profile': 1,
#  'rseqc_clipping_profile': 1,
#  'rseqc_insertion_profile': 1,
#  'rawtools': 1,
#  'filter_tabular': 1,
#  'bamSplit': 1,
#  'poretools_events': 1,
#  'bedtools_bed12tobed6': 1,
#  'picrust_predict_metagenomes': 1,
#  'ebi_metagenomics_run_downloader': 1,
#  'regionalgam_autocor_acf': 1,
#  'Kraken2Tax': 1,
#  'extract': 1,
#  'gmap_build': 1,
#  'fastq_mcf': 1,
#  'species_tree_generator': 1,
#  'seqtk_comp': 1,
#  'mothur_summary_qual': 1,
#  'EMBOSS: infoseq46': 1,
#  'mothur_collect_single': 1,
#  'openbabel_addh': 1,
#  'scater_plot_exprs_freq': 1,
#  'scater_plot_tsne': 1,
#  'bamtools_split': 1,
#  'snpEff_get_chr_names': 1,
#  'countKeggs': 1,
#  'geneList': 1,
#  'tarean_exp': 1,
#  'repeatexplorer2': 1,
#  'interactive_tool_jupyter_notebook': 1,
#  'describe_samples': 1,
#  'hicexplorer_chicdifferentialtest': 1,
#  'schicexplorer_schicplotconsensusmatrices': 1,
#  'interactive_tool_phinch': 1,
#  'bg_diamond_makedb': 1,
#  'gatk_analyze_covariates': 1,
#  'interactive_tool_fairdom_send': 1,
#  'mummer_mummerplot': 1,
#  'poretools_tabular': 1,
#  'ggplot2_pca': 1,
#  'gdal_gdalinfo': 1,
#  'climate_stripes': 1,
#  'poretools_qualdist': 1,
#  'poretools_nucdist': 1,
#  'poretools_occupancy': 1,
#  'poretools_yield_plot': 1,
#  'padel': 1,
#  'cp_image_math': 1,
#  'TargetedFileConverter': 1,
#  'hicexplorer_hicnormalize': 1,
#  'vsearch_sorting': 1,
#  'peakcalling_sicer': 1,
#  'correctGCBias': 2,
#  'deeptools_bigwigCompare': 2,
#  'methtools_tiling': 2,
#  'cshl_easyjoin': 2,
#  'rbc_rnabob': 2,
#  'predict_pipeline': 2,
#  'EMBOSS: textsearch98': 2,
#  'picard_ValidateSamFile': 2,
#  'picard_EstimateLibraryComplexity': 2,
#  'get_child_terms': 2,
#  'bg_statistical_hypothesis_testing': 2,
#  'rnalfoldz': 2,
#  'rnalfold': 2,
#  'rnafold': 2,
#  'EMBOSS: needle56': 2,
#  'Determine_BC': 2,
#  'pieplots_macs': 2,
#  'umi_tools_group': 2,
#  'FeatureLinkerUnlabeledKD': 2,
#  'idpquery': 2,
#  'Extract_RNA_seq_Evidence': 2,
#  'gff_filter_by_attribute': 2,
#  'FROGS_preprocess': 2,
#  'kraken-filter': 2,
#  'cd_hit_dup': 2,
#  'idr': 2,
#  'tp_text_file_with_recurring_lines': 2,
#  'PercolatorAdapter': 2,
#  'ProteinResolver': 2,
#  'bam-filter': 2,
#  'mycrobiota-split-multi-otutable': 2,
#  '16Saligner': 2,
#  'ExtractFASTAfromFASTQ': 2,
#  'ChooseTag': 2,
#  'TrimByN': 2,
#  'TrimByLength': 2,
#  'rarefaction': 2,
#  'seurat': 2,
#  'smf_utils_filter-by-energy': 2,
#  'fastq collapser': 2,
#  'aggregate': 2,
#  'calc_fitness': 2,
#  'Interval2Maf1': 2,
#  'sm_mirdeep2core_without_Randfold': 2,
#  'sm_mapper': 2,
#  'megahit_contig2fastg': 2,
#  'filter_columns': 2,
#  'vcfcheck': 2,
#  'prepare_ligand': 2,
#  'picard_CollectGcBiasMetrics': 2,
#  'ctb_spectrophore_search': 2,
#  'ctb_subsearch': 2,
#  'ctb_stripit': 2,
#  'ctb_rdkit_describtors': 2,
#  'trinity_define_clusters_by_cutting_tree': 2,
#  'trinotate': 2,
#  'hicexplorer_hicplotviewpoint': 2,
#  'CONVERTER_bed_to_fli_0': 2,
#  'express': 2,
#  'CONVERTER_fasta_to_2bit': 2,
#  'retr_pepatlas1': 2,
#  'prot_features': 2,
#  'poretools_hist': 2,
#  'Kneeplot': 2,
#  'morpheus': 2,
#  'poretools_qualpos': 2,
#  'poretools_winner': 2,
#  'minfi_getsnp': 2,
#  'gd_calc_freq': 2,
#  'seqtk_mergefa': 2,
#  'massbank_ws_searchspectrum': 2,
#  'regionalgam_plot_trend': 2,
#  'sopra_wpc': 2,
#  'SequenceCoverageCalculator': 2,
#  'polyA': 2,
#  'assign': 2,
#  'filter': 2,
#  'mdanalysis_hbonds': 2,
#  'macs2_filterdup': 2,
#  'ambertools_antechamber': 2,
#  'tbvcfreport': 2,
#  'tb_profiler_profile': 2,
#  'qc_stdout': 2,
#  'vsearch_search': 2,
#  'picard_DownsampleSam': 2,
#  'samtools_fixmate': 2,
#  'rdpmulticlassifier': 2,
#  'cluster_otu': 2,
#  'diffexp': 2,
#  'scater_normalize': 2,
#  'scmap_scmap_cluster': 2,
#  'scmap_scmap_cell': 2,
#  'metaphlan2_hutlab': 2,
#  'macs2_bdgbroadcall': 2,
#  'lcaclassifier_wrapper_script 1': 2,
#  'uit_megablast_wrapper': 2,
#  'filter_16s_wrapper_script 1': 2,
#  'abims_CAMERA_combinexsAnnos': 2,
#  'schicexplorer_schicplotclusterprofiles': 2,
#  'schicexplorer_schicqualitycontrol': 2,
#  'poretools_times': 2,
#  'SnpEff-cds-report': 2,
#  'trinity_super_transcripts': 2,
#  'structure': 2,
#  'kraken-mpa-report': 2,
#  'draw_circos': 2,
#  '2_map': 2,
#  'mummer_show_coords': 2,
#  'mummer_delta_filter': 2,
#  'dada2_assignTaxonomyAddspecies': 2,
#  'vcfbreakcreatemulti': 2,
#  'vcfaddinfo': 2,
#  'biom_convert': 2,
#  'dada2_dada': 2,
#  'dada2_learnErrors': 2,
#  'pick_open_reference_otus': 2,
#  'cp_gray_to_color': 2,
#  'cp_display_data_on_image': 2,
#  'mimodd_info': 2,
#  'microsat_pal_finder': 2,
#  'percolator_input_converters': 2,
#  'bedtools_mergebedgraph': 3,
#  'vcffilter': 3,
#  'gemini_burden': 3,
#  'cshl_multijoin': 3,
#  'cshl_fastx_nucleotides_distribution': 3,
#  'gbk_to_orf': 3,
#  'bedtools_clusterbed': 3,
#  'sklearn_numeric_clustering': 3,
#  'EMBOSS: wordcount109': 3,
#  'abims_xcms_summary': 3,
#  'EMBOSS: backtranseq2': 3,
#  'rgweblogo3': 3,
#  'hgv_snpFreq': 3,
#  'idpqonvertEmbedder': 3,
#  'FROGS_affiliation_OTU': 3,
#  'metaphlan_hclust_heatmap': 3,
#  'velveth_jgi': 3,
#  'varscan_copynumber': 3,
#  'pileup_interval': 3,
#  'mycrobiota-krona-mothur': 3,
#  'Flash': 3,
#  'vcfgenotypes': 3,
#  'ruvseq': 3,
#  'bedtools_complementbed': 3,
#  'select_random_lines': 3,
#  'flaimapper': 3,
#  'msconvert_win': 3,
#  'cd_hit_protein': 3,
#  'wtdbg': 3,
#  'mtbls520_06_import_traits': 3,
#  'mtbls520_05a_import_maf': 3,
#  'mtbls520_03_quality_control': 3,
#  'ctb_remove_protonation_state': 3,
#  'ctb_osra': 3,
#  'genomespace_exporter': 3,
#  'bcftools_plugin_counts': 3,
#  'bedtools_groupbybed': 3,
#  'iframe': 3,
#  'vigiechiro_bilanenrichirp': 3,
#  'tabular_to_csv': 3,
#  'MetaProSIP': 3,
#  'gsnap': 3,
#  'damid_deseq2_to_peaks': 3,
#  'damid_interpolate': 3,
#  'usearch_derep_full': 3,
#  'openbabel_svg_depiction': 3,
#  'Krona': 3,
#  'hicexplorer_chicsignificantinteractions': 3,
#  'hicexplorer_chicaggregatestatistic': 3,
#  'schicexplorer_schicconsensusmatrices': 3,
#  'schicexplorer_schicclustersvl': 3,
#  'sklearn_stacking_ensemble_models': 3,
#  'enasearch_search_data': 3,
#  '6_parse_discord': 3,
#  '4_filter_sam': 3,
#  '3_filter_single_pair': 3,
#  'reactome_analysis': 3,
#  'dada2_filterAndTrim': 3,
#  'rnaspades': 3,
#  'cp_relate_objects': 3,
#  'cloudmap_variant_discovery_mapping': 3,
#  'dt_profiler': 4,
#  'gemini_lof_sieve': 4,
#  'gemini_roh': 4,
#  'vcf2pgSnp': 4,
#  'cshl_fastq_quality_boxplot': 4,
#  'bg_column_arrange_by_header': 4,
#  'hgv_linkToGProfile': 4,
#  'vcfflatten2': 4,
#  'map_peptides_to_bed': 4,
#  'blast_plus_remote_blastp': 4,
#  'qiime_assign_taxonomy': 4,
#  'ggplot_histogram': 4,
#  'chipsequtil_maptoknowngenes': 4,
#  'nonpareil': 4,
#  'rbc_splitfasta': 4,
#  'FROGS_clustering': 4,
#  'FROGS_remove_chimera': 4,
#  'FROGS_filters': 4,
#  'graphclust_aggregate_alignments': 4,
#  'gatk_depth_of_coverage': 4,
#  'correct_barcodes': 4,
#  'align_families': 4,
#  'TrimPrimer': 4,
#  'Btrim64': 4,
#  'AREsite2_REST': 4,
#  'msconvert_nix': 4,
#  'qiime_filter_alignment': 4,
#  'qiime_split_libraries': 4,
#  'qiime_summarize_taxa_through_plots': 4,
#  'qiime_make_otu_table': 4,
#  'bcftools_stats': 4,
#  'build_ucsc_custom_track_1': 4,
#  'OpenSwathAssayGenerator': 4,
#  'OpenSwathDecoyGenerator': 4,
#  'msnbase-filter-merge-msms': 4,
#  'mtbls520_04_preparations': 4,
#  'xcms-dilutionfilter': 4,
#  'xcms-blankfilter': 4,
#  'xcms-correct-rt': 4,
#  'xcms-collect-peaks': 4,
#  'miranda': 4,
#  'deeptools_bam_pe_fragmentsize': 4,
#  'ctb_alignit': 4,
#  'ctb_alignit_create_db': 4,
#  'ctb_shapeit': 4,
#  'trinity_samples_qccheck': 4,
#  'clusterprofiler_go': 4,
#  'keras_model_builder': 4,
#  'keras_model_config': 4,
#  'rseqc_RNA_fragment_size': 4,
#  'BAMTagHistogram': 4,
#  'DetectBeadSynthesisErrors_querysorted': 4,
#  'TrimStartingSequence': 4,
#  'basil': 4,
#  'xcms_export_samplemetadata': 4,
#  'mothur_get_relabund': 4,
#  'minion_search_adapter': 4,
#  'scater_plot_pca': 4,
#  'scater_plot_dist_scatter': 4,
#  'paired_fastq_filtering': 4,
#  'trinity_gene_to_trans_map': 4,
#  'hicexplorer_chicqualitycontrol': 4,
#  'hicexplorer_chicviewpointbackgroundmodel': 4,
#  'schicexplorer_schicnormalize': 4,
#  'gatk_table_recalibration': 4,
#  '5_calc_stat': 4,
#  'CONVERTER_interval_to_bed12_0': 4,
#  'fpocket': 4,
#  'idr_download_by_ids': 4,
#  'xchem_transfs_scoring': 4,
#  'liftOver1': 4,
#  'cp_measure_image_intensity': 4,
#  'cp_measure_image_area_occupied': 4,
#  'cp_measure_image_quality': 4,
#  'cp_measure_object_intensity': 4,
#  'cp_measure_texture': 4,
#  'cp_measure_granularity': 4,
#  'cp_save_images': 4,
#  'cp_mask_image': 4,
#  'cp_enhance_or_suppress_features': 4,
#  'pyprophet_export': 4,
#  'diapysef': 4,
#  'iedb_api': 4,
#  'exonerate': 4,
#  'trap': 5,
#  'bams2ratio': 5,
#  'msconvert2_raw': 5,
#  'translate_bed_sequences': 5,
#  'gemini_interactions': 5,
#  'rnbeads': 5,
#  'Psortb': 5,
#  'ctb_silicos_qed': 5,
#  'sklear_numeric_clustering': 5,
#  'tp_sort_rows': 5,
#  'tsne': 5,
#  'stacks_genotypes': 5,
#  'idpqonvert': 5,
#  'kraken': 5,
#  'kraken-translate': 5,
#  'bundle_collection': 5,
#  'ete_homology_classifier': 5,
#  'mass_spectrometry_imaging_segmentations': 5,
#  'mycrobiota-otutable_add_blast': 5,
#  'pynast': 5,
#  'vkmz_qt': 5,
#  'retrieve_from_hpa': 5,
#  'tables_arithmetic_operations': 5,
#  'ip_imageinfo': 5,
#  'progressivemauve': 5,
#  'snp_sites': 5,
#  'samtools_markdup': 5,
#  'openbabel_genProp': 5,
#  'hicexplorer_chicviewpoint': 5,
#  '1_create_conf': 5,
#  'ctb_remSmall': 6,
#  'deeptools_correctGCBias': 6,
#  'EMBOSS: newseq59': 6,
#  'gemini_pathways': 6,
#  'bedtools_closestbed': 6,
#  'genbank_to_gff': 6,
#  'ProteinInference': 6,
#  'gops_cluster_1': 6,
#  'split_tabular_columns': 6,
#  'idpassemble': 6,
#  'CometAdapter': 6,
#  'Extractor': 6,
#  'vegan_rarefaction': 6,
#  'vcf_filter': 6,
#  'raceid3': 6,
#  'MapStatistics': 6,
#  'CONVERTER_sam_to_unsorted_bam': 6,
#  'make_families': 6,
#  'transpose': 6,
#  'mothur_trim_seqs': 6,
#  'uparse': 6,
#  'uchime': 6,
#  'smf_utils_estimate-energy': 6,
#  'smf_utils_extract-boxed-sequences': 6,
#  'react_cal_pipeline': 6,
#  'bcftools_mpileup': 6,
#  'passatutto': 6,
#  'rseqc_FPKM_count': 6,
#  'ctb_ob_addh': 6,
#  'ctb_ob_svg_depiction': 6,
#  'ctb_multi_obgrep': 6,
#  'mimodd_header': 6,
#  'clusterprofiler_bitr': 6,
#  'chipeakanno_annopeaks': 6,
#  'picard_MergeBamAlignment': 6,
#  'PolyATrimmer': 6,
#  'sklearn_clf_metrics': 6,
#  'create_or_update': 6,
#  'mothur_make_design': 6,
#  'mummer_mummer': 6,
#  'cat': 6,
#  'sucos_docking_scoring': 6,
#  'map_reads_otu': 6,
#  'phyml': 6,
#  'cat_bins': 6,
#  'gatk_variant_filtration': 6,
#  'gatk_variant_select': 6,
#  'conf4circos': 6,
#  'cluter_profiler': 6,
#  'iuc_deseq2': 6,
#  'stoceps_glm_group': 6,
#  'cp_common': 6,
#  'vg_deconstruct': 6,
#  'cp_measure_object_size_shape': 6,
#  'vsearch_clustering': 6,
#  'seq2hla': 6,
#  'bgchem_fragment_merger': 7,
#  'find_in_reference': 7,
#  'CONVERTER_bed_to_bgzip_0': 7,
#  'gemini_stats': 7,
#  'eden_vectorizer': 7,
#  'vcfselectsamples': 7,
#  'GeneModelMapper': 7,
#  'minfi_dmr': 7,
#  'minfi_qc': 7,
#  'minfi_getbeta': 7,
#  'viennarna_rnaplot': 7,
#  'modencode_peakcalling_spp': 7,
#  'rseqc_read_duplication': 7,
#  'secure_hash_message_digest': 7,
#  'extract_element_from_collection': 7,
#  'mycrobiota-make-multi-otutable': 7,
#  'gatk2_depth_of_coverage': 7,
#  'picard_CollectWgsMetrics': 7,
#  'ctb_confab': 7,
#  'ctb_obgrep': 7,
#  'CONVERTER_bam_to_bigwig_0': 7,
#  'gd_rank_terms': 7,
#  'ip_count_objects': 7,
#  'mummer_nucmer': 7,
#  'keras_train_and_eval': 7,
#  'stacks2_populations': 7,
#  'ivar_consensus': 7,
#  'cp_export_to_spreadsheet': 7,
#  'computeGCBias': 8,
#  'trnascan': 8,
#  'macs2_bdgcmp': 8,
#  'eden_sequence_converter': 8,
#  'mlocarna': 8,
#  'ggplot_point': 8,
#  'qiime_make_otu_heatmap': 8,
#  'bctools_remove_tail': 8,
#  'mothur_get_seqs': 8,
#  'minfi_ppfun': 8,
#  'bam_to_bigwig': 8,
#  'vcftools_annotate': 8,
#  'ip_projective_transformation': 8,
#  'FeatureFinderMetabo': 8,
#  'sequence_content_trimmer': 8,
#  'mycrobiota-qc-report': 8,
#  'paralyzer': 8,
#  'minfi_rset': 8,
#  'minfi_maptogenome': 8,
#  'cshl_princeton_fastx_barcode_splitter': 8,
#  'vcftools_slice': 8,
#  'camera-group-fwhm': 8,
#  'camera-annotate-peaks': 8,
#  'msnbase-read-msms': 8,
#  'xcms-group-peaks': 8,
#  'ctb_np-likeness-calculator': 8,
#  'trinity_analyze_diff_expr': 8,
#  'trinity_run_de_analysis': 8,
#  'trinity_contig_exn50_statistic': 8,
#  'rna_abbased_data': 8,
#  'FilterBAM': 8,
#  'TagBamWithReadSequenceExtended': 8,
#  'picard_FastqToSam': 8,
#  'mothur_summary_tax': 8,
#  'stoceps_maketablecarrer': 8,
#  'sccaf_asses_merger': 8,
#  'gatk_count_covariates': 8,
#  'sRNAPipe': 8,
#  'sixgill_build': 8,
#  'ivar_variants': 8,
#  'pyprophet_score': 8,
#  'fragmenter': 9,
#  'CONVERTER_interval_to_bgzip_0': 9,
#  'ssake': 9,
#  'EMBOSS: extractseq35': 9,
#  'heatmap2': 9,
#  'CONVERTER_fasta_to_fai': 9,
#  'qiime_make_phylogeny': 9,
#  'wsdl_hmdb': 9,
#  'gatk_realigner_target_creator': 9,
#  'w4mclstrpeakpics': 9,
#  'bcftools_filter': 9,
#  'ctb_opsin': 9,
#  'ctb_sdf2fps': 9,
#  'normalization': 9,
#  'mothur_make_lefse': 9,
#  'idba_hybrid': 9,
#  'sceasy_convert': 9,
#  'maxquant_mqpar': 9,
#  'metagene_annotator': 9,
#  'cp_convert_objects_to_image': 9,
#  'pyprophet_merge': 9,
#  'snpSift_geneSets': 10,
#  'gtf2bedgraph': 10,
#  'Digestor': 10,
#  'tophat_fusion_post': 10,
#  'deeptools_plot_enrichment': 10,
#  'picard_MarkDuplicatesWithMateCigar': 10,
#  'ete_genetree_splitter': 10,
#  'gatk_unified_genotyper': 10,
#  'ia_coordinates_of_roi': 10,
#  'fastq_combiner': 10,
#  'dunovo': 10,
#  'mycrobiota-correct-replicates': 10,
#  'bp_genbank2gff3': 10,
#  'smf_utils_fix-fasta-headers': 10,
#  'metfrag-cli-batch-multiple': 10,
#  'camera-find-adducts': 10,
#  'xcms-find-peaks': 10,
#  'intarna': 10,
#  'compose_text_param': 10,
#  'seurat_dim_plot': 10,
#  'snpSift_rmInfo': 10,
#  '_dropletBarcodePlot': 10,
#  'mira_assembler': 10,
#  'lofreq_indelqual': 10,
#  'chira_collapse': 10,
#  'moabs': 10,
#  'parmconv': 10,
#  'mimodd_rebase': 10,
#  'PicardASMetrics': 11,
#  'ctb_ob_genProp': 11,
#  'cshl_fastx_quality_statistics': 11,
#  'snpeff_to_peptides': 11,
#  'bedtools_genomecoveragebed_histogram': 11,
#  'MassCalculator': 11,
#  'metams_runGC': 11,
#  'xpath': 11,
#  'gops_merge_1': 11,
#  'trim_reads': 11,
#  'qiime_align_seqs': 11,
#  'CONVERTER_gff_to_interval_index_0': 11,
#  'trinity_filter_low_expr_transcripts': 11,
#  'stoceps_glm': 11,
#  'samtools_merge': 11,
#  'lofreq_alnqual': 11,
#  'openms_protein_quantifier': 12,
#  'vcffixup': 12,
#  'wiggle2simple1': 12,
#  'get_sequences': 12,
#  'bcftools_call': 12,
#  'lfq_protein_quant': 12,
#  'IDMassAccuracy': 12,
#  'diffbind-embl': 12,
#  'idr-embl': 12,
#  'vcfannotate': 12,
#  'peptidegenomiccoordinate': 12,
#  'get_read_pipeline': 12,
#  'goslimmer': 12,
#  'freebayes_wrapper': 12,
#  'msms2metfrag-multiple': 12,
#  'map-msms2camera': 12,
#  'mdanalysis_dihedral': 12,
#  'mdanalysis_distance': 12,
#  'Jvenn': 12,
#  'mothur_split_abund': 12,
#  'stoceps_filteringsp': 12,
#  'ip_overlay_segmentation': 12,
#  'sccaf_asses': 12,
#  'scanpy_regress_variable': 12,
#  'sklearn_generalized_linear': 12,
#  'vg_convert': 12,
#  'vg_view': 12,
#  'minia': 12,
#  'cp_identify_primary_objects': 12,
#  'bamCoverage_deepTools': 13,
#  'bedtools_annotatebed': 13,
#  'blastxml_to_tabular_selectable': 13,
#  'iqtree': 13,
#  'QCCalculator': 13,
#  'rseqc_junction_saturation': 13,
#  'gmx_merge_topology_files': 13,
#  'replace_chromosome_names': 13,
#  'Transformation': 13,
#  'ambertools_acpype': 13,
#  'keras_batch_models': 13,
#  'scater_create_qcmetric_ready_sce': 13,
#  'rdock_sort_filter': 13,
#  'cp_cellprofiler': 13,
#  'decoyfasta': 14,
#  'msgfplus': 14,
#  'length_and_gc_content': 14,
#  'MAF_To_Fasta1': 14,
#  'annotateMyIDs': 14,
#  'nn_classifier': 14,
#  'NFS_transfer': 14,
#  'pep_pointer': 14,
#  'camera-find-isotopes': 14,
#  'IDconverter': 14,
#  'scater_filter': 14,
#  'vmd_hbonds': 14,
#  'enumerate_charges': 14,
#  'gatk2_variant_annotator': 15,
#  'silac_analyzer': 15,
#  'bedtools_unionbedgraph': 15,
#  'flanking_features_1': 15,
#  'muscle': 15,
#  'meme_psp_gen': 15,
#  'kallisto_pseudo': 15,
#  'CONVERTER_fastqgz_to_fastq': 15,
#  'poretools_stats': 15,
#  'prepare_ligands_for_docking': 15,
#  'CONVERTER_bam_to_coodinate_sorted_bam': 15,
#  'dropletutils_empty_drops': 15,
#  'meta_flye': 15,
#  'hyphy_gard': 15,
#  'rdock_rbcavity': 15,
#  'chira_quantify': 15,
#  'vcfsort': 16,
#  'blast_parser': 16,
#  'hcluster_sg': 16,
#  'samtools_bedcov': 16,
#  'mass_spectrometry_imaging_classification': 16,
#  'mtbls520_07_species_diversity': 16,
#  'mdanalysis_ramachandran_plot': 16,
#  'ctb_chemfp_nxn_clustering': 16,
#  'ctb_remDuplicates': 16,
#  'mimodd_reheader': 16,
#  'vcftools_compare': 16,
#  'seqtk_mergepe': 16,
#  'peptide_genomic_coordinate': 16,
#  'jq': 16,
#  'pyprophet_protein': 16,
#  'pyprophet_peptide': 16,
#  'blastxml_to_tabular': 17,
#  'proteomics_search_protein_prophet_1': 17,
#  'bedtools_coveragebed_counts': 17,
#  'gatk_indel_realigner': 17,
#  'FeatureFinderCentroided': 17,
#  'plotly_parallel_coordinates_plot': 17,
#  'viz_overlay_moving_and_fixed_image': 17,
#  'smf_utils_find-boxes': 17,
#  'ip_scale_image': 17,
#  'cat_summarise': 17,
#  'openbabel_filter': 17,
#  'bigwig_to_bedgraph': 18,
#  'vegan_diversity': 18,
#  'snpfinder': 18,
#  'samtools_flag_filter': 18,
#  'cat_multiple': 18,
#  'fgsea': 18,
#  'minfi_dmp': 18,
#  'bismark_pretty_report': 18,
#  'seqtk_sample': 18,
#  'ip_binary_to_labelimage': 18,
#  'seurat_filter_cells': 18,
#  'bio3d_pca_visualize': 18,
#  'cat_add_names': 18,
#  'cat_contigs': 18,
#  'seqwish': 18,
#  'picard_BamIndexStats': 19,
#  'bcftools_view': 19,
#  'myrimatch': 19,
#  'scale_image': 19,
#  'macs2_predictd': 19,
#  'imagecoordinates_flipaxis': 19,
#  'regionalgam_glmmpql': 19,
#  'bamCorrelate_deepTools': 20,
#  'bamFingerprint': 20,
#  'openms_id_mapper': 20,
#  'CONVERTER_bed_to_gff_0': 20,
#  'gafa': 20,
#  'gatk2_unified_genotyper': 20,
#  'bg_find_subsequences': 20,
#  'minfi_dropsnp': 20,
#  'lastz_wrapper_2': 20,
#  'infernal_cmstat': 20,
#  'ip_coordinates_of_roi': 20,
#  'regionalgam_gls': 20,
#  'seurat_find_markers': 20,
#  'seurat_create_seurat_object': 20,
#  'gmx_restraints': 20,
#  'chira_merge': 20,
#  'chira_map': 20,
#  'stoceps_trend_indic': 20,
#  'eukaryotic_ncbi_submission': 21,
#  'glimmer_not-knowlegde-based': 21,
#  'picard_SamToFastq': 21,
#  'bg_diamond': 21,
#  'gene2exon1': 21,
#  'sailfish': 21,
#  'treebest_best': 21,
#  'sklearn_nn_classifier': 21,
#  'OpenSwathWorkflow': 21,
#  'gdal_ogr2ogr': 21,
#  'regionalgam_flight_curve': 21,
#  'sklearn_train_test_eval': 21,
#  'proteomics_search_tandem_1': 22,
#  'Draw_phylogram': 22,
#  'humann2_regroup_table': 22,
#  'qiime_pick_otus': 22,
#  'mothur_get_communitytype': 22,
#  'MapAlignerPoseClustering': 22,
#  'kraken-report': 22,
#  'column_order_header_sort': 22,
#  'pipmir': 22,
#  'seurat_normalise_data': 22,
#  'hmmer_hmmscan': 22,
#  'EMBOSS: shuffleseq87': 23,
#  'sam2interval': 23,
#  'bedtools_map': 23,
#  'trinity_abundance_estimates_to_matrix': 23,
#  'spocc_occ': 23,
#  'xcms_plot_chromatogram': 23,
#  'seurat_find_variable_genes': 23,
#  'fasta_concatenate0': 23,
#  'Sff_extractor': 23,
#  'bedtools_intersectBed': 24,
#  'cor2': 24,
#  'vcftools_isec': 24,
#  'picard_FixMateInformation': 24,
#  'disco': 24,
#  'hcluster_sg_parser': 24,
#  're_he_maldi_image_registration': 24,
#  'graphclust_align_cluster': 24,
#  'raceid_main': 24,
#  'aggregate_scores_in_intervals2': 24,
#  'ip_viz_overlay_moving_and_fixed_image': 24,
#  'collection_element_identifiers': 24,
#  'camera-prepareoutput': 24,
#  'mdanalysis_rdf': 24,
#  'metaquantome_stat': 24,
#  'sklearn_estimator_attributes': 24,
#  'seurat_scale_data': 24,
#  'run_sccaf': 24,
#  'Nucleosome': 25,
#  'viennarna_rnaalifold': 25,
#  'samtools_slice_bam': 25,
#  'dropletutils_read_10x': 25,
#  'bam2wig': 26,
#  'openms_id_file_converter': 26,
#  'CONVERTER_fasta_to_tabular': 26,
#  'blast2go': 26,
#  'clustalw': 26,
#  'MapRTTransformer': 26,
#  'mummer_dnadiff': 26,
#  'param_value_from_file': 26,
#  'sccaf_regress_out': 26,
#  'gmx_trj': 26,
#  'hyphy_absrel': 26,
#  'hmmer_jackhmmer': 26,
#  'msconvert3_raw': 27,
#  'EMBOSS: water107': 27,
#  'seq_composition': 27,
#  'resistome_analyzer': 27,
#  'deeptools_plot_coverage': 27,
#  'mimodd_convert': 27,
#  'MQoutputfilter': 27,
#  'seqtk_subseq': 27,
#  'ncbi_acc_download': 27,
#  'filter_bed_on_splice_junctions': 28,
#  'ucsc-twobittofa': 28,
#  'heinz_visualization': 28,
#  'ip_landmark_registration': 28,
#  'mdanalysis_cosine_analysis': 28,
#  'crosscontamination_barcode_filter': 28,
#  'methtools_filter': 29,
#  'charts': 29,
#  'PicardInsertSize': 29,
#  'term_id_vs_term_def': 29,
#  'ggplot2_histogram': 29,
#  'bismark_methylation_extractor': 29,
#  'msnbase_readmsdata': 29,
#  'seurat_export_cellbrowser': 29,
#  'ctb_mordred_descriptors': 29,
#  'maxbin2': 29,
#  'bamCompare_deepTools': 30,
#  'bedtools_windowbed': 30,
#  'rbc_rnacode': 30,
#  'gd_raxml': 30,
#  'sklearn_model_validation': 30,
#  'snpSift_int': 30,
#  'seurat_run_pca': 30,
#  '_salmon_kallisto_mtx_to_10x': 30,
#  'medaka_consensus': 30,
#  'chira_extract': 30,
#  'megablast_xml_parser': 31,
#  'gff_to_sequence': 31,
#  't_coffee': 31,
#  'deeptools_plot_pca': 31,
#  'gatk2_variant_filtration': 32,
#  'CONVERTER_Bam_Bai_0': 32,
#  'gff2bed1': 32,
#  'cshl_fasta_nucleotides_changer': 32,
#  'qiime_pick_rep_set': 32,
#  'fasplit': 32,
#  'gemini_actionable_mutations': 32,
#  'minfi_mset': 32,
#  'mothur_pairwise_seqs': 32,
#  'ip_histogram_equalization': 32,
#  'seurat_run_tsne': 32,
#  'tb_variant_filter': 32,
#  'ctb_filter': 33,
#  'rnaz': 33,
#  'graphicsmagick_image_montage': 33,
#  'gatk4_mutect2': 33,
#  'CONVERTER_bedgraph_to_bigwig': 34,
#  'picard_NormalizeFasta': 34,
#  'tp_unfold_column_tool': 34,
#  'resize_coordinate_window': 34,
#  'openbabel_remDuplicates': 34,
#  'scanpy_remove_confounders': 34,
#  'iReport': 35,
#  'gmx_makendx': 35,
#  'uniprotxml_downloader': 35,
#  'proteomics_search_peptide_prophet_1': 36,
#  'rsem_prepare_reference': 36,
#  'cshl_fastx_renamer': 36,
#  'cuffquant': 36,
#  'scanpy_parameter_iterator': 36,
#  'scanpy_normalize': 36,
#  'xchem_pose_scoring': 36,
#  'sklearn_feature_selection': 37,
#  'sucos_max_score': 37,
#  'vt_normalize': 38,
#  'lca1': 38,
#  'ip_projective_transformation_points': 38,
#  'modencode_peakcalling_macs2': 39,
#  'cshl_fasta_formatter': 39,
#  'EMBOSS: fuzztran39': 39,
#  'tp_uniq_tool': 39,
#  'cast': 39,
#  'mass_spectrometry_imaging_ion_images': 39,
#  'egsea': 39,
#  'deeptools_alignmentsieve': 39,
#  'ip_convertimage': 39,
#  'ncbi_blastx_wrapper': 40,
#  'rsem_calculate_expression': 40,
#  'qiime_pick_closed_reference_otus': 40,
#  'svm_classifier': 40,
#  'graphclust_glob_report_no_align': 40,
#  'cmv': 40,
#  'locarna_multiple': 40,
#  'regionalgam_ab_index': 40,
#  'seurat_find_clusters': 40,
#  'seurat_read10x': 40,
#  'circos': 40,
#  'alevin': 40,
#  'mmpbsa_mmgbsa': 40,
#  'gatk2_variant_select': 41,
#  'mz_to_sqlite': 41,
#  '__TAG_FROM_FILE__': 41,
#  'hicexplorer_hictransform': 42,
#  'bedtools_multicovtbed': 42,
#  'lofreq_filter': 42,
#  'aragorn_trna': 43,
#  'ctb_remIons': 44,
#  'prokaryotic_ncbi_submission': 44,
#  'IDFileConverter': 44,
#  'thermo_raw_file_converter': 44,
#  'maker_map_ids': 44,
#  'maxquant': 44,
#  'cuffnorm': 45,
#  'mothur_classify_rf': 45,
#  'mothur_lefse': 45,
#  'snippy_core': 45,
#  'mothur_parsimony': 46,
#  'FeatureLinkerUnlabeledQT': 46,
#  'fastq_stats': 46,
#  'gemini_inheritance': 46,
#  'scanpy_plot_embed': 46,
#  'sklearn_train_test_split': 46,
#  'flexbar': 47,
#  'pileup_parser': 47,
#  'abyss-pe': 47,
#  'qiime_count_seqs': 48,
#  'hca_matrix_downloader': 48,
#  '_ensembl_gtf2gene_list': 48,
#  'ctb_pubchem_download_as_smiles': 49,
#  'ucsc_cell_browser': 49,
#  'ctb_change_title': 50,
#  'fastq_trimmer': 50,
#  'RNAlien': 50,
#  'bismark_deduplicate': 50,
#  'signalp3': 51,
#  'chembl': 51,
#  'sam_bw_filter': 52,
#  'roary': 52,
#  'bed_to_protein_map': 52,
#  'r_correlation_matrix': 53,
#  'rmcontamination': 53,
#  'cshl_fastx_artifacts_filter': 53,
#  'melt': 53,
#  'bctools_remove_spurious_events': 53,
#  'prepare_receptor': 53,
#  'rseqc_junction_annotation': 53,
#  'scaffold2fasta': 54,
#  'glimmer_build-icm': 54,
#  'cummerbund_to_cuffdiff': 54,
#  'fastq_paired_end_splitter': 54,
#  'cardinal_spectra_plots': 54,
#  'heatmapper_deepTools': 55,
#  'Batch_correction': 55,
#  'circgraph': 55,
#  'snpsift_vartype': 55,
#  'poretools_extract': 55,
#  'peakcalling_macs': 56,
#  'bedtools_subtractbed': 56,
#  'mothur_heatmap_bin': 56,
#  'cds_essential_variability': 56,
#  'vigiechiro_bilanenrichipf': 56,
#  'pathview': 56,
#  'qualimap_bamqc': 56,
#  'stacks2_denovomap': 56,
#  'qualimap_rnaseq': 56,
#  'gatk2_reduce_reads': 58,
#  'tophat': 58,
#  'cshl_cut_tool': 58,
#  'ctb_simsearch': 58,
#  'gspan': 58,
#  '__APPLY_RULES__': 58,
#  'ip_2d_split_binaryimage_by_watershed': 58,
#  'CONVERTER_interval_to_bedstrict_0': 59,
#  'mass_spectrometry_imaging_mzplots': 59,
#  'heinz_bum': 59,
#  'ip_threshold': 59,
#  'ctb_compound_convert': 60,
#  'pureclip': 60,
#  'blast_reciprocal_best_hits': 60,
#  'flash': 60,
#  'vigiechiro_idcorrect_2ndlayer': 60,
#  'diffbind': 60,
#  'Datamash': 61,
#  'p_clip_peaks': 61,
#  'piranha': 61,
#  'Heatmap': 61,
#  'openbabel_change_title': 62,
#  'rarefaction_analyzer': 63,
#  'ctb_online_data_fetch': 64,
#  'deeptools_correct_gc_bias': 64,
#  'bandage_info': 64,
#  'ip_filter_standard': 64,
#  'ncbi_rpsblast_wrapper': 65,
#  'abims_CAMERA_annotateDiffreport': 65,
#  'column_remove_by_header': 65,
#  'xcms_merge': 65,
#  'prinseq': 65,
#  'prepare_box': 65,
#  'meme_dreme': 66,
#  '__EXTRACT_DATASET__': 66,
#  'metaquantome_viz': 66,
#  'metaquantome_filter': 66,
#  ...}

# %%
p_freq
# Out:
# {'cshl_find_and_replace,CONVERTER_interval_to_bed_0,CONVERTER_interval_to_bedstrict_0,addValue,mergeCols1,Cut1': 1,
#  'get_flanks1,gops_intersect_1,Extract genomic DNA 1': 1,
#  'get_flanks1,Extract genomic DNA 1,fasta2tab,Show beginning1,tab2fasta,meme_meme': 1,
#  'get_flanks1,gops_intersect_1,gops_subtract_1,Count1,barchart_gnuplot': 1,
#  'peakcalling_macs14,cshl_awk_tool,gops_intersect_1,CONVERTER_interval_to_bed_0,Count1': 1,
#  'get_flanks1,gops_intersect_1,CONVERTER_interval_to_bed_0,Count1': 1,
#  'bam_to_sam,PicardASMetrics': 1,
#  'peakcalling_macs14,cshl_awk_tool,gops_intersect_1,CONVERTER_interval_to_bed_0,Extract genomic DNA 1,fasta2tab,Show beginning1,tab2fasta,meme_meme': 1,
#  'get_flanks1,gops_intersect_1,CONVERTER_interval_to_bed_0,Extract genomic DNA 1,fasta2tab,Show beginning1,tab2fasta,meme_meme': 1,
#  'bams2ratio,heatmapper': 1,
#  'Extract genomic DNA 1,fasta2tab,Show beginning1,tab2fasta': 1,
#  'gops_intersect_1,cshl_uniq_tool,Cut1': 1,
#  'Filter1,Paste1,Cut1,XY_Plot_1': 1,
#  'Add_a_column1,Cut1,XY_Plot_1': 1,
#  'Filter1,Paste1,Cut1,Show tail1': 1,
#  'Add_a_column1,Cut1,Show tail1': 1,
#  'bedtools_multiintersectbed,Add_a_column1,Cut1,sort1,cshl_uniq_tool': 1,
#  'bedtools_multiintersectbed,Add_a_column1,Filter1,gops_intersect_1,Cut1,sort1,cshl_uniq_tool': 1,
#  'bismark_bowtie,sam_to_bam,samtools_rmdup,methtools_calling': 1,
#  'cshl_sort_header,Filter1,Add_a_column1,Cut1,methtools_filter,Paste1': 1,
#  'cshl_sort_header,Filter1,Add_a_column1,Cut1,bedtools_intersectbed_bam,methtools_filter,Paste1': 1,
#  'cshl_sort_header,Filter1,bedtools_intersectbed_bam,addValue,Cut1,methtools_filter,Paste1': 1,
#  'cshl_sort_header,Filter1,bedtools_intersectbed_bam,methtools_filter,Paste1': 1,
#  'cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,methtools_filter,methtools_dmr,Filter1': 1,
#  'cshl_sort_header,methtools_plot': 1,
#  'Filter1,bedtools_intersectbed_bam,Paste1,cat1': 1,
#  'bedtools_intersectbed_bam,methtools_filter,methtools_dmr': 1,
#  'Add_a_column1,Cut1,Filter1': 1,
#  'Convert characters1,Filter1,Add_a_column1,Cut1': 1,
#  'trim_galore,tophat2,bam2wig': 1,
#  'Add_a_column1,Cut1,wig_to_bigWig': 1,
#  'Filter1,bedtools_intersectbed_bam': 1,
#  'addValue,Cut1,heatmapper': 1,
#  'Filter1,wig_to_bigWig': 1,
#  'Filter1,addValue,mergeCols1,Cut1': 1,
#  'smooth_running_window,bedtools_intersectbed_bam,methtools_filter,methtools_dmr': 1,
#  'trim_galore,bowtie2,sam_merge2,samtools_rmdup,bam2wig': 1,
#  'Filter1,bedtools_intersectbed_bam,smooth_running_window,Cut1,Paste1,r_correlation_matrix': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup': 1,
#  'Cut1,gops_intersect_1,Add_a_column1,Summary_Statistics1': 1,
#  'get_flanks1,Count1,barchart_gnuplot': 1,
#  'cshl_sort_header,cshl_uniq_tool': 1,
#  'Cut1,cshl_uniq_tool,sort1': 1,
#  'cshl_find_and_replace,gops_intersect_1,Cut1,cshl_uniq_tool': 1,
#  'Cut1,cshl_uniq_tool': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup,sam_merge2,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window,bedtools_intersectbed_bam,methtools_filter,methtools_dmr,Summary_Statistics1': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup,sam_merge2,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window,bedtools_intersectbed_bam,methtools_filter,methtools_dmr,Filter1,Summary_Statistics1': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup,sam_merge2,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window,bedtools_intersectbed_bam,Filter1,Summary_Statistics1': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup,sam_merge2,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window,bedtools_intersectbed_bam,methtools_filter,wc_gnu': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup,sam_merge2,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window,bedtools_intersectbed_bam,methtools_filter,methtools_dmr,Cut1,wig_to_bigWig': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup,sam_merge2,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window,bedtools_intersectbed_bam,methtools_filter,methtools_dmr,addValue,mergeCols1,Cut1,wig_to_bigWig': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup,sam_merge2,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window,bedtools_intersectbed_bam,methtools_filter,methtools_dmr,Filter1,Add_a_column1,Cut1,wig_to_bigWig': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup,sam_merge2,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window,bedtools_intersectbed_bam,methtools_filter,methtools_dmr,Filter1,addValue,mergeCols1,Cut1,wig_to_bigWig': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup,sam_merge2,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window,bedtools_intersectbed_bam,Filter1,Add_a_column1,Cut1,wig_to_bigWig': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup,sam_merge2,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window,bedtools_intersectbed_bam,Filter1,addValue,mergeCols1,Cut1,wig_to_bigWig': 1,
#  'fastq_quality_trimmer,bismark_bowtie,samtools_rmdup,sam_merge2,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window,bedtools_intersectbed_bam,addValue,mergeCols1,Cut1,wig_to_bigWig': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,computeMatrix,heatmapper_deepTools': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,wig_to_bigWig,computeMatrix,heatmapper_deepTools': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,computeMatrix,heatmapper_deepTools': 1,
#  'methtools_calling,cshl_sort_header,Filter1,Add_a_column1,Cut1,computeMatrix,heatmapper_deepTools': 1,
#  'methtools_calling,cshl_sort_header,Filter1,Add_a_column1,Cut1,bedtools_intersectbed_bam,computeMatrix,heatmapper_deepTools': 1,
#  'methtools_calling,cshl_sort_header,Filter1,Add_a_column1,Cut1,wig_to_bigWig,computeMatrix,heatmapper_deepTools': 1,
#  'methtools_calling,cshl_sort_header,cshl_uniq_tool,Filter1,Add_a_column1,Cut1,computeMatrix,heatmapper_deepTools': 1,
#  'methtools_calling,cshl_sort_header,cshl_uniq_tool,Filter1,Add_a_column1,Cut1,bedtools_intersectbed_bam,computeMatrix,heatmapper_deepTools': 1,
#  'methtools_calling,cshl_sort_header,cshl_uniq_tool,Filter1,Add_a_column1,Cut1,wig_to_bigWig,computeMatrix,heatmapper_deepTools': 1,
#  'CONVERTER_interval_to_bedstrict_0,cshl_grep_tool,Add_a_column1,Cut1,Summary_Statistics1,Filter1': 1,
#  'peakcalling_macs14,computeMatrix,heatmapper_deepTools': 1,
#  'tophat2,cuffdiff,join1,Cut1,Show tail1': 1,
#  'tophat2,cuffdiff,cshl_sort_header,addValue,Cut1,Show tail1': 1,
#  'Filter1,gtf_filter_by_attribute_values_list': 1,
#  'Filter1,Extract_features1,gtf_filter_by_attribute_values_list': 1,
#  'Filter1,heatmapper,Remove beginning1,Remove_ending': 1,
#  'cat1,Filter1,Add_a_column1,Cut1,wig_to_bigWig': 1,
#  'cat1,Filter1,Add_a_column1,addValue,mergeCols1,Cut1,wig_to_bigWig': 1,
#  'Remove beginning1,Filter1,sort1': 1,
#  'Remove beginning1,Filter1,bedtools_intersectbed_bam,Grouping1,join1,cshl_word_list_grep': 1,
#  'Filter1,bedtools_intersectbed_bam,Grouping1,join1,Cut1': 1,
#  'ctb_remIons,ctb_remSmall,ctb_filter,ctb_compound_convert': 1,
#  'bgchem_fragment_merger,ctb_compound_convert': 1,
#  'sort1,Cut1,Paste1': 1,
#  'trim_galore,bowtie2,samtools_rmdup,sam_merge2,bamCoverage_deepTools': 1,
#  'heatmapper,Cut1': 1,
#  'deeptools_computeGCBias,correctGCBias': 1,
#  'bamCoverage_deepTools,computeMatrix,heatmapper_deepTools': 1,
#  'deeptools_computeGCBias,deeptools_correctGCBias,deeptools_bigwigCompare': 1,
#  'addValue,Cut1,bedtools_intersectbed_bam,methtools_tiling': 1,
#  'Filter1,bedtools_intersectbed_bam,Grouping1,join1,Cut1,cor2': 1,
#  'gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_haplotype_caller': 1,
#  'gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_haplotype_caller': 1,
#  'cshl_sort_header,cshl_easyjoin': 1,
#  'gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_haplotype_caller,gatk2_variant_select': 1,
#  'gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_haplotype_caller,gatk2_variant_select': 1,
#  'gatk2_variant_select,gatk2_variant_annotator,snpEff,cshl_word_list_grep': 1,
#  'gatk2_variant_select,vcftools_isec,snpSift_filter,snpSift_geneSets': 1,
#  'gatk2_variant_select,vcftools_isec,snpEff,snpSift_filter,snpSift_geneSets': 1,
#  'openms_id_file_converter,openms_id_mapper': 1,
#  'silac_analyzer,openms_id_mapper': 1,
#  'bowtie2,samtools_rmdup,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads': 1,
#  'bowtie2,samtools_rmdup,gatk2_indel_realigner,gatk2_print_reads': 1,
#  'bowtie2,samtools_rmdup,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads': 1,
#  'bowtie2,samtools_rmdup,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads': 1,
#  'openms_id_file_converter,openms_id_mapper,openms_protein_quantifier': 1,
#  'openms_id_file_converter,openms_protein_quantifier': 1,
#  'silac_analyzer,openms_id_mapper,openms_protein_quantifier': 1,
#  'bowtie2,modencode_peakcalling_macs2': 1,
#  'bowtie2,bamCoverage_deepTools': 1,
#  'samtools_rmdup,bamCoverage_deepTools': 1,
#  'bedtools_coveragebed_counts,Add_a_column1': 1,
#  'bowtie2,samtools_rmdup,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_haplotype_caller': 1,
#  'bowtie2,samtools_rmdup,gatk2_indel_realigner,gatk2_print_reads,gatk2_haplotype_caller': 1,
#  'bowtie2,samtools_rmdup,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_haplotype_caller': 1,
#  'bowtie2,samtools_rmdup,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_haplotype_caller': 1,
#  'bedtools_coveragebed_counts,Add_a_column1,Grouping1': 1,
#  'bowtie2,rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller': 1,
#  'bowtie2,rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller': 1,
#  'bowtie2,rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller': 1,
#  'bowtie2,rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller': 1,
#  'snpSift_filter,cshl_word_list_grep': 1,
#  'vcftools_merge,vcftools_isec': 1,
#  'vcftools_merge,vcftools_isec,snpEff,snpSift_filter,cshl_word_list_grep': 1,
#  'bedtools_intersectbed_bam,Filter1,Grouping1': 1,
#  'msconvert3_raw,proteomics_search_tandem_1,proteomics_search_peptide_prophet_1,proteomics_search_protein_prophet_1': 1,
#  'gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'sort1,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'cat1,fasta2tab,find_in_reference': 1,
#  'addValue,mergeCols1': 1,
#  'Cut1,cshl_find_and_replace': 1,
#  'addValue,mergeCols1,Cut1,Count1,barchart_gnuplot': 1,
#  'addValue,mergeCols1,Cut1,CONVERTER_interval_to_bed_0,CONVERTER_interval_to_bedstrict_0': 1,
#  'Cut1,cshl_find_and_replace,gops_intersect_1': 1,
#  'Cut1,cshl_find_and_replace,CONVERTER_interval_to_bed_0,CONVERTER_interval_to_bedstrict_0,barchart_gnuplot': 1,
#  'get_flanks1,gops_intersect_1,barchart_gnuplot': 1,
#  'Cut1,cshl_find_and_replace,Count1,CONVERTER_interval_to_bed_0,CONVERTER_interval_to_bedstrict_0': 1,
#  'Cut1,cshl_find_and_replace,gops_intersect_1,Count1,CONVERTER_interval_to_bed_0,CONVERTER_interval_to_bedstrict_0': 1,
#  'get_flanks1,gops_intersect_1,Count1,CONVERTER_interval_to_bed_0,CONVERTER_interval_to_bedstrict_0': 1,
#  'Cut1,cshl_find_and_replace,Count1,barchart_gnuplot': 1,
#  'Cut1,cshl_find_and_replace,gops_intersect_1,Count1,barchart_gnuplot': 1,
#  'CONVERTER_interval_to_bed_0,gops_intersect_1,Count1,barchart_gnuplot': 1,
#  'cshl_find_and_replace,gops_intersect_1,Count1': 1,
#  'get_flanks1,CONVERTER_interval_to_bed_0,gops_intersect_1,Count1,barchart_gnuplot': 1,
#  'addValue,mergeCols1,Cut1,cshl_find_and_replace,CONVERTER_interval_to_bed_0,CONVERTER_interval_to_bedstrict_0,gops_intersect_1,Count1,barchart_gnuplot': 1,
#  'bowtie2,rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'bowtie2,rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'bowtie2,rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'bowtie2,rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'cshl_sed_tool,cshl_find_and_replace,CONVERTER_interval_to_bed_0,CONVERTER_interval_to_bedstrict_0': 1,
#  'cshl_sed_tool,cshl_find_and_replace,gops_intersect_1,Count1,barchart_gnuplot': 1,
#  'CONVERTER_interval_to_bed_0,deeptools_computeMatrix': 1,
#  'methtools_calling,cshl_sort_header': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,CONVERTER_interval_to_bed_0,bedtools_intersectbed_bam,Cut1,Paste1,r_correlation_matrix': 1,
#  'picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'picard_ReorderSam,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'picard_ReorderSam,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_select,gatk2_variant_annotator,snpEff': 1,
#  'bedtools_genomecoveragebed_bedgraph,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,bedtools_genomecoveragebed_bedgraph,CONVERTER_interval_to_bed_0,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,gops_intersect_1,Paste1,Cut1,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,gops_intersect_1,methtools_dmr,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,gops_intersect_1,methtools_dmr,methtools_plot': 1,
#  'methtools_calling,gops_intersect_1,methtools_plot': 1,
#  'methtools_calling,gops_intersect_1,Paste1,Cut1,r_correlation_matrix': 1,
#  'methtools_calling,gops_intersect_1,r_correlation_matrix': 1,
#  'CONVERTER_interval_to_bgzip_0,CONVERTER_interval_to_bed_0': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_plot,CONVERTER_interval_to_bed_0': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,methtools_plot,CONVERTER_interval_to_bed_0': 1,
#  'methtools_calling,cshl_cut_tool,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,cshl_cut_tool,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_cut_tool,Paste1,r_correlation_matrix': 1,
#  'methtools_calling,Cut1,CONVERTER_interval_to_bgzip_0,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,Cut1,CONVERTER_interval_to_bed_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,CONVERTER_interval_to_bgzip_0,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,CONVERTER_interval_to_bed_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'Cut1,CONVERTER_interval_to_bed_0,bedtools_genomecoveragebed_bedgraph,CONVERTER_interval_to_bgzip_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'Cut1,CONVERTER_interval_to_bed_0,bedtools_genomecoveragebed_bedgraph,CONVERTER_interval_to_bgzip_0,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'Cut1,CONVERTER_interval_to_bed_0,bed_to_bigBed': 1,
#  'methtools_calling,Cut1,bedtools_intersectbed_bam,methtools_dmr,gops_intersect_1': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,Cut1,bedtools_intersectbed_bam,cshl_cut_tool,Paste1,r_correlation_matrix': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,Cut1,gops_intersect_1': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_interval_to_bedstrict_0,gops_intersect_1': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,gops_intersect_1': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_interval_to_bedstrict_0,gops_intersect_1': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,Cut1,gops_intersect_1': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,Cut1,CONVERTER_interval_to_bed_0,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,Cut1,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_interval_to_bedstrict_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,CONVERTER_interval_to_bed_0,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_interval_to_bedstrict_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,Cut1,CONVERTER_interval_to_bed_0,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,Cut1,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_interval_to_bedstrict_0,methtools_plot': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_plot': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_interval_to_bedstrict_0,methtools_plot': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,methtools_plot': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,Cut1,Paste1,r_correlation_matrix': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,Paste1,r_correlation_matrix': 1,
#  'CONVERTER_Bam_Bai_0,methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,Cut1,Paste1,r_correlation_matrix': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,methtools_dmr,gops_intersect_1': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,Cut1,gops_intersect_1': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_plot,CONVERTER_interval_to_bgzip_0,CONVERTER_interval_to_bed_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,methtools_plot,CONVERTER_interval_to_bgzip_0,CONVERTER_interval_to_bed_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,CONVERTER_bedgraph_to_bigwig,CONVERTER_interval_to_bgzip_0,CONVERTER_interval_to_bed_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,methtools_plot,CONVERTER_interval_to_bgzip_0,CONVERTER_interval_to_bed_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,methtools_dmr,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,methtools_dmr,methtools_plot,CONVERTER_interval_to_bgzip_0,CONVERTER_interval_to_bed_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,Cut1,CONVERTER_bedgraph_to_bigwig,CONVERTER_interval_to_bgzip_0,CONVERTER_interval_to_bed_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,join1,r_correlation_matrix': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,Cut1,Paste1,r_correlation_matrix': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,Cut1,join1,r_correlation_matrix': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Add_a_column1': 1,
#  'methtools_calling,cshl_sort_header,methtools_destrand,bedtools_intersectbed_bam,Add_a_column1': 1,
#  'CONVERTER_bed_to_bgzip_0,CONVERTER_bed_gff_or_vcf_to_bigwig_0': 1,
#  'methtools_calling,Cut1,Grep1,gops_intersect_1': 1,
#  'methtools_calling,Cut1,gops_intersect_1': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,Cut1,Grep1,gops_intersect_1': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,Cut1,gops_intersect_1': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,Grep1,gops_intersect_1': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,Cut1,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,Cut1,Paste1,r_correlation_matrix': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,Cut1,Add_a_column1': 1,
#  'methtools_calling,bedtools_genomecoveragebed_bedgraph': 1,
#  'methtools_calling,cshl_sort_header,Cut1,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_bed_to_bgzip_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,Cut1,CONVERTER_bedgraph_to_bigwig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_bed_to_bgzip_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,Cut1,bedtools_intersectbed_bam,r_correlation_matrix': 1,
#  'methtools_calling,cshl_sort_header,Cut1,Paste1,r_correlation_matrix': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,r_correlation_matrix': 1,
#  'CONVERTER_bed_gff_or_vcf_to_bigwig_0,deeptools_computeMatrix,deeptools_profiler': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,deeptools_computeMatrix,deeptools_profiler': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,Cut1,wig_to_bigWig,deeptools_computeMatrix,deeptools_profiler': 1,
#  'CONVERTER_bed_gff_or_vcf_to_bigwig_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,gops_intersect_1': 1,
#  'methtools_calling,cshl_sort_header,CONVERTER_bed_gff_or_vcf_to_bigwig_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_bed_gff_or_vcf_to_bigwig_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,Extract genomic DNA 1': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,Cut1,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,Cut1,bedtools_intersectbed_bam,methtools_dmr,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,Cut1,bedtools_intersectbed_bam,cshl_cut_tool,Paste1,r_correlation_matrix': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,Cut1,bedtools_intersectbed_bam,cshl_cut_tool,join1,r_correlation_matrix': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,bedtools_intersectbed_bam,cshl_cut_tool,Paste1,r_correlation_matrix': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,bedtools_intersectbed_bam,cshl_cut_tool,join1,r_correlation_matrix': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,methtools_destrand': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,Cut1,bedtools_intersectbed_bam,methtools_plot': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,Cut1,bedtools_intersectbed_bam,methtools_dmr,methtools_plot': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,bedtools_intersectbed_bam,methtools_plot': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,methtools_plot': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,Cut1,Add_a_column1': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,Cut1,bedtools_intersectbed_bam,methtools_dmr,Extract genomic DNA 1': 1,
#  'methtools_calling,CONVERTER_interval_to_bedstrict_0,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,Extract genomic DNA 1': 1,
#  'methtools_destrand,CONVERTER_interval_to_bed_0': 1,
#  'methtools_calling,sort1,gops_intersect_1,methtools_dmr,Cut1,wig_to_bigWig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,sort1,gops_intersect_1,methtools_dmr,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,sort1,gops_intersect_1,methtools_dmr,Cut1,Paste1,r_correlation_matrix': 1,
#  'methtools_calling,Cut1,bedtools_intersectbed_bam': 1,
#  'methtools_calling,sort1,gops_intersect_1,methtools_dmr,bedtools_intersectbed_bam': 1,
#  'methtools_calling,sort1,gops_intersect_1,methtools_dmr,Cut1,bedtools_intersectbed_bam': 1,
#  'methtools_calling,sort1,gops_intersect_1,methtools_dmr,Extract genomic DNA 1': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_interval_to_bedstrict_0,gops_intersect_1': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_interval_to_bedstrict_0,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'cshl_cut_tool,CONVERTER_bedgraph_to_bigwig,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_interval_to_bedstrict_0,methtools_plot': 1,
#  'methtools_calling,cshl_sort_header,bedtools_intersectbed_bam,methtools_dmr,CONVERTER_interval_to_bedstrict_0,Extract genomic DNA 1': 1,
#  'Extract genomic DNA 1,EMBOSS: geecee41,Convert characters1,Remove beginning1,Paste1,Cut1,Add_a_column1,XY_Plot_1': 1,
#  'Cut1,cshl_find_and_replace,CONVERTER_interval_to_bed_0': 1,
#  'Cut1,cshl_find_and_replace,Count1': 1,
#  'Cut1,cshl_find_and_replace,gops_intersect_1,Count1': 1,
#  'deseq2,hgv_david': 1,
#  'cufflinks,htseq-count': 1,
#  'Show beginning1,cshl_fastx_trimmer,bowtie2,deeptools_bamCoverage': 1,
#  'Show beginning1,cshl_fastx_trimmer,bowtie2,htseq-count,deseq2': 1,
#  'sed_stream_editor,htseq-count,deseq2': 1,
#  'sed_stream_editor,Remove beginning1,htseq-count,deseq2': 1,
#  'Show beginning1,Show tail1': 1,
#  'bwa_mem,rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_apply_recalibration': 1,
#  'bwa_mem,rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_recalibrator,gatk2_variant_apply_recalibration': 1,
#  'bwa_mem,rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_apply_recalibration': 1,
#  'bwa_mem,rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_recalibrator,gatk2_variant_apply_recalibration': 1,
#  'bwa_mem,rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_apply_recalibration': 1,
#  'bwa_mem,rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_recalibrator,gatk2_variant_apply_recalibration': 1,
#  'bwa_mem,rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_apply_recalibration': 1,
#  'bwa_mem,rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_recalibrator,gatk2_variant_apply_recalibration': 1,
#  'ncbi_blastp_wrapper,Cut1,gops_intersect_1,Grouping1': 1,
#  'ncbi_blastp_wrapper,Filter1,Cut1,gops_intersect_1,Grouping1': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_apply_recalibration': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_recalibrator,gatk2_variant_apply_recalibration': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_apply_recalibration': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_recalibrator,gatk2_variant_apply_recalibration': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_apply_recalibration': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_recalibrator,gatk2_variant_apply_recalibration': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_apply_recalibration': 1,
#  'rgPicardMarkDups,picard_ReorderSam,gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_recalibrator,gatk2_variant_apply_recalibration': 1,
#  'CONVERTER_interval_to_bed_0,bedtools_intersectbed_bam,smooth_running_window,Cut1,Paste1,random_lines1': 1,
#  'CONVERTER_interval_to_bed_0,bedtools_multiintersectbed,Filter1,bedtools_intersectbed_bam,smooth_running_window,Cut1,Paste1,random_lines1': 1,
#  'bowtie2,bedtools_bamtobed,Add_a_column1,Filter1,bedtools_mergebed,Extract genomic DNA 1,fasta_filter_by_length,infernal_cmsearch,Grouping1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Add_a_column1,Filter1,bedtools_mergebed,Extract genomic DNA 1,infernal_cmsearch,Grouping1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Add_a_column1,Filter1,cshl_sort_header,Grouping1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Add_a_column1,Filter1,Grouping1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Add_a_column1,Filter1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Extract genomic DNA 1,fasta_filter_by_length,infernal_cmsearch,Filter1,cshl_sort_header,Grouping1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Extract genomic DNA 1,fasta_filter_by_length,infernal_cmsearch,Filter1,Grouping1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Extract genomic DNA 1,fasta_filter_by_length,infernal_cmsearch,Filter1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Extract genomic DNA 1,fasta_filter_by_length,infernal_cmsearch,Grouping1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Extract genomic DNA 1,infernal_cmsearch,Filter1,cshl_sort_header,Grouping1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Extract genomic DNA 1,infernal_cmsearch,Filter1,Grouping1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Extract genomic DNA 1,infernal_cmsearch,Filter1,sort1': 1,
#  'bowtie2,bedtools_bamtobed,Extract genomic DNA 1,infernal_cmsearch,Grouping1,sort1': 1,
#  'bwa_wrapper,Grouping1,sort1': 1,
#  'bwa_mem,Show tail1,Grouping1,sort1': 1,
#  'bwa_wrapper,samtools_flagstat': 1,
#  'bowtie2,bedtools_bamtobed,Add_a_column1,Filter1,Summary_Statistics1': 1,
#  'bowtie2,bedtools_bamtobed,Add_a_column1,Filter1,bedtools_mergebed,Extract genomic DNA 1,fasta_compute_length,Summary_Statistics1': 1,
#  'bowtie2,bedtools_bamtobed,Extract genomic DNA 1,fasta_filter_by_length,infernal_cmsearch,Filter1,Summary_Statistics1': 1,
#  'bowtie2,bedtools_bamtobed,Extract genomic DNA 1,infernal_cmsearch,Filter1,Summary_Statistics1': 1,
#  'bwa_mem,wc_gnu': 1,
#  'bwa_mem,Grep1': 1,
#  'bedtools_mergebed,Extract genomic DNA 1,fasta_filter_by_length,ncbi_blastn_wrapper,Filter1,Grep1': 1,
#  'bwa_mem,sam2interval': 1,
#  'CONVERTER_bed_to_gff_0,Remove beginning1,addValue,Cut1,Filter1': 1,
#  'CONVERTER_bed_to_gff_0,Remove beginning1,addValue,mergeCols1,Cut1,Filter1': 1,
#  'CONVERTER_bed_to_gff_0,Remove beginning1,Cut1,Filter1': 1,
#  'samtools_rmdup,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window': 1,
#  'bowtie2,fastq_to_fasta_python,ncbi_blastn_wrapper,Filter1,Grep1': 1,
#  'trim_galore,bowtie2,bedtools_bamtobed,join1': 1,
#  'bowtie2,fastq_to_fasta_python,ssake,ncbi_blastn_wrapper,Cut1,Convert characters1,Grouping1,sort1': 1,
#  'bowtie2,fastq_to_fasta_python,ssake,ncbi_blastn_wrapper,Grouping1,sort1': 1,
#  'bowtie2,fastq_to_fasta_python,fasta_filter_by_length,sample_seqs,ncbi_blastn_wrapper,Cut1,Convert characters1,Grouping1,sort1': 1,
#  'bowtie2,fastq_to_fasta_python,fasta_filter_by_length,sample_seqs,ncbi_blastn_wrapper,Grouping1,sort1': 1,
#  'bowtie2,fastq_to_fasta_python,ssake,ncbi_blastn_wrapper,Grep1': 1,
#  'bowtie2,fastq_to_fasta_python,fasta_filter_by_length,sample_seqs,ncbi_blastn_wrapper,Grep1': 1,
#  'bowtie2,fastq_to_fasta_python,ssake,ncbi_blastn_wrapper,Show beginning1': 1,
#  'bowtie2,fastq_to_fasta_python,fasta_filter_by_length,sample_seqs,ncbi_blastn_wrapper,Show beginning1': 1,
#  'join1,cshl_sort_header': 1,
#  'EMBOSS: newseq59,EMBOSS: water107': 1,
#  'EMBOSS: water107,cshl_grep_tool,trimmer,Convert characters1,Cut1': 1,
#  'EMBOSS: shuffleseq87,EMBOSS: water107,cshl_grep_tool,trimmer,sort1': 1,
#  'Cut1,Remove beginning1': 1,
#  'deeptools_computeMatrix,deeptools_profiler,Cut1': 1,
#  'deeptools_computeMatrix,deeptools_profiler,Cut1,Paste1': 1,
#  'deeptools_computeGCBias,deeptools_correctGCBias,deeptools_bamCoverage': 1,
#  'bowtie2,rgPicardMarkDups,picard_ReorderSam,samtools_mpileup': 1,
#  'vcffilter,snpSift_annotate': 1,
#  'wig_to_bigWig,cshl_word_list_grep,Cut1,cat1': 1,
#  'bowtie2,rgPicardMarkDups,picard_ReorderSam,freebayes,vcffilter,snpSift_annotate,snpEff': 1,
#  'gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_apply_recalibration,vcftools_merge,cshl_cut_tool,snpSift_filter,snpEff': 1,
#  'gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_base_recalibrator,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_recalibrator,gatk2_variant_apply_recalibration,vcftools_merge,cshl_cut_tool,snpSift_filter,snpEff': 1,
#  'gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_apply_recalibration,vcftools_merge,cshl_cut_tool,snpSift_filter,snpEff': 1,
#  'gatk2_realigner_target_creator,gatk2_indel_realigner,gatk2_print_reads,gatk2_reduce_reads,gatk2_haplotype_caller,gatk2_variant_recalibrator,gatk2_variant_apply_recalibration,vcftools_merge,cshl_cut_tool,snpSift_filter,snpEff': 1,
#  'trim_galore,bismark_bowtie2,samtools_sort,samtools_rmdup': 1,
#  'trim_galore,bismark_bowtie2,samtools_sort,samtools_rmdup,methtools_calling,cshl_sort_header,methtools_destrand,smooth_running_window': 1,
#  'bismark_bowtie,samtools_sort,samtools_rmdup': 1,
#  'Count1,charts': 1,
#  'gops_intersect_1,Count1,charts': 1,
#  'trim_galore,bismark_bowtie,samtools_rmdup,samtools_sort,methtools_calling,methtools_destrand,Filter1,smooth_running_window,Cut1': 1,
#  'Convert characters1,Remove beginning1,Grouping1,join1': 1,
#  'ncbi_makeblastdb,ncbi_blastn_wrapper,Grep1': 1,
#  'EMBOSS: transeq101,fasta_compute_length,join1,cshl_awk_replace_in_column,Add_a_column1,Cut1,gops_intersect_1,Grouping1': 1,
#  'EMBOSS: transeq101,EMBOSS: fuzzpro38,Grep1,join1,cshl_awk_replace_in_column,Add_a_column1,Cut1,gops_intersect_1,Grouping1': 1,
#  'augustus,Extract_features1,Grep1': 1,
#  'trim_galore,bowtie2,samtools_rmdup,sam_merge2,macs2_callpeak': 1,
#  'trim_galore,bowtie2,samtools_rmdup,sam_merge2,deeptools_bamCompare': 1,
#  'cshl_word_list_grep,Grouping1,wc_gnu': 1,
#  'ctb_online_data_fetch,ctb_change_title,ctb_compound_convert,ctb_chemfp_mol2fps,ctb_simsearch,Filter1,comp1,cat1': 1,
#  'ctb_online_data_fetch,ctb_change_title,ctb_compound_convert,comp1,cat1': 1,
#  'ctb_online_data_fetch,ctb_change_title,ctb_compound_convert,cat1': 1,
#  'cufflinks,mergeCols1,cshl_word_list_grep,sort1': 1,
#  'cufflinks,Remove beginning1,Grouping1,mergeCols1,cshl_word_list_grep,sort1': 1,
#  'cufflinks,Remove beginning1,Grouping1,Cut1,cshl_word_list_grep,sort1': 1,
#  'tophat2,cufflinks,mergeCols1,cshl_word_list_grep,sort1': 1,
#  'tophat2,cufflinks,Remove beginning1,Grouping1,mergeCols1,cshl_word_list_grep,sort1': 1,
#  'tophat2,cufflinks,Remove beginning1,Grouping1,Cut1,cshl_word_list_grep,sort1': 1,
#  'cshl_awk_tool,cshl_find_and_replace,CONVERTER_interval_to_bed_0,gops_intersect_1,Count1': 1,
#  'cshl_awk_tool,cshl_find_and_replace,CONVERTER_interval_to_bed_0,CONVERTER_bed_gff_or_vcf_to_bigwig_0': 1,
#  'cshl_find_and_replace,gops_intersect_1,bg_uniq': 1,
#  'cshl_find_and_replace,gops_intersect_1,bg_uniq,Cut1,wc_gnu': 1,
#  'Add_a_column1,Cut1,wc_gnu': 1,
#  'get_flanks1,bedtools_subtractbed': 1,
#  'bed2gff1,Remove beginning1,htseq_count,Grouping1': 1,
#  'gemini_load,gemini_burden': 1,
#  'gemini_load,gemini_comp_hets': 1,
#  'gemini_load,gemini_windower': 1,
#  'gemini_load,gemini_query': 1,
#  'gemini_load,gemini_de_novo': 1,
#  'gemini_load,gemini_pathways': 1,
#  'gemini_load,gemini_interactions': 1,
#  'freebayes,vcfallelicprimitives,vt_normalize,snpEff,snpSift_filter,gemini_load': 1,
#  'tophat2,deeptools_bamCoverage': 1,
#  'Remove beginning1,Convert characters1,Filter1,Cut1,cat1,cshl_awk_replace_in_column': 1,
#  'Remove beginning1,Convert characters1,Filter1,cat1,cshl_awk_replace_in_column': 1,
#  'glimmer_build-icm,glimmer_knowlegde-based,Remove beginning1,Convert characters1,addValue,cshl_awk_replace_in_column,Cut1,cat1,CONVERTER_bed_gff_or_vcf_to_bigwig_0': 1,
#  'glimmer_build-icm,glimmer_knowlegde-based,Remove beginning1,Convert characters1,addValue,cshl_awk_replace_in_column,Filter1,cat1,CONVERTER_bed_gff_or_vcf_to_bigwig_0': 1,
#  'glimmer_build-icm,glimmer_knowlegde-based,Remove beginning1,Convert characters1,addValue,cshl_awk_replace_in_column,Filter1,Cut1,cat1,CONVERTER_bed_gff_or_vcf_to_bigwig_0': 1,
#  'glimmer_build-icm,glimmer_knowlegde-based,Remove beginning1,Convert characters1,addValue,Cut1,cshl_find_and_replace': 1,
#  'varscan,snpSift_annotate,snpEff,gemini_load': 1,
#  'gatk2_haplotype_caller,gatk2_variant_apply_recalibration,vcftools_merge,cshl_cut_tool,snpEff': 1,
#  'gatk2_haplotype_caller,gatk2_variant_recalibrator,gatk2_variant_apply_recalibration,vcftools_merge,cshl_cut_tool,snpEff': 1,
#  'bedtools_intersectbed_bam,Datamash,join1,Cut1': 1,
#  'Convert characters1,DatamashTranspose,cshl_word_list_grep': 1,
#  'ncbi_makeblastdb,ncbi_blastn_wrapper,blastxml_to_top_descr,seq_filter_by_id': 1,
#  'join1,sort1,Cut1': 1,
#  'join1,sort1,Cut1,Grep1': 1,
#  'fastq_to_fasta_python,ncbi_blastn_wrapper,sort1': 1,
#  'bowtie2,rgPicardMarkDups,bamFilter,bedtools_bamtofastq,cshl_fastq_to_fasta,ncbi_blastn_wrapper,sort1': 1,
#  'sed_stream_editor,bg_uniq': 1,
#  'htseq_count,Add_a_column1,Cut1,Remove beginning1,sort1,cshl_multijoin': 1,
#  'htseq_count,join1,Add_a_column1,Cut1,Remove beginning1,sort1,cshl_multijoin': 1,
#  'samtools_rmdup,cufflinks,Cut1,Remove beginning1,sort1,cshl_multijoin': 1,
#  'samtools_rmdup,cufflinks,Cut1': 1,
#  'cufflinks,Cut1': 1,
#  'rseqc_bam2wig,wig_to_bigWig': 1,
#  'cshl_sed_tool,addValue,mergeCols1,Cut1': 1,
#  'mergeCols1,random_lines1': 1,
#  'createInterval,cat1,addValue,Convert characters1': 1,
#  'XTandemAdapter,PeptideIndexer,IDPosteriorErrorProbability,IDMerger,IDMapper': 1,
#  'fasta2tab,join1,Cut1': 1,
#  'fastq_groomer,trim_galore,tophat2,samtools_rmdup,sam_merge2,cufflinks': 1,
#  'XTandemAdapter,PeptideIndexer,IDPosteriorErrorProbability': 1,
#  'FileFilter,FeatureFinderMultiplex': 1,
#  'XTandemAdapter,PeptideIndexer,IDPosteriorErrorProbability,IDMerger': 1,
#  'XTandemAdapter,PeptideIndexer,FalseDiscoveryRate,IDFilter,IDMerger': 1,
#  'fasta2tab,tp_easyjoin_tool,Cut1,DatamashOps,Summary_Statistics1': 1,
#  'Remove beginning1,Convert characters1,Summary_Statistics1': 1,
#  'Remove beginning1,Convert characters1,Filter1,Summary_Statistics1': 1,
#  'Remove beginning1,Convert characters1,Filter1,Cut1,DatamashOps,Summary_Statistics1': 1,
#  'augustus,Extract_features1,regex_replace,cshl_find_and_replace,mergeCols1,Cut1,tab2fasta': 1,
#  'augustus,Extract_features1,regex_replace,cshl_find_and_replace,addValue,mergeCols1,Cut1,tab2fasta': 1,
#  'augustus,fasta2tab,addValue,mergeCols1,Cut1,tab2fasta': 1,
#  'augustus,fasta2tab,addValue,cshl_find_and_replace,mergeCols1,Cut1,tab2fasta': 1,
#  'fastq_to_fasta_python,fasta2tab': 1,
#  'trim_galore,tophat2,cufflinks,cuffmerge': 1,
#  'fasta2tab,addValue,Cut1,tab2fasta': 1,
#  'Extract_features1,regex_replace,addValue,Cut1,tab2fasta': 1,
#  'fasta_filter_by_length,ncbi_blastn_wrapper,Grep1': 1,
#  'fastq_to_fasta_python,fasta_filter_by_length,ncbi_blastn_wrapper,Grep1': 1,
#  'tophat2,samtools_sort': 1,
#  'tp_replace_in_column,get_flanks1,gops_intersect_1': 1,
#  'tp_replace_in_column,CONVERTER_interval_to_bed_0,get_flanks1,gops_intersect_1': 1,
#  'tp_replace_in_column,cshl_awk_tool,get_flanks1,gops_intersect_1,Count1,tp_sort_header_tool': 1,
#  'tp_replace_in_column,cshl_awk_tool,CONVERTER_interval_to_bed_0,gops_intersect_1,Count1,barchart_gnuplot': 1,
#  'tp_replace_in_column,cshl_awk_tool,CONVERTER_interval_to_bed_0,gops_intersect_1,Count1,Grep1': 1,
#  'get_flanks1,gops_intersect_1,Count1,Grep1': 1,
#  'cshl_awk_tool,tp_find_and_replace,Filter1': 1,
#  'cshl_awk_tool,tp_find_and_replace,CONVERTER_interval_to_bed_0,gops_intersect_1,Count1,barchart_gnuplot': 1,
#  'fastq_to_fasta_python,fasta2tab,Grouping1,tp_sort_header_tool': 1,
#  'fastq_to_fasta_python,fasta2tab,Grouping1,tp_sort_header_tool,tp_head_tool': 1,
#  'cutadapt,fastq_to_fasta_python,fasta2tab,Grouping1,tp_sort_header_tool,tp_head_tool': 1,
#  'fastq_groomer,trim_galore,bwa_wrapper': 1,
#  'Convert characters1,tp_easyjoin_tool,Filter1': 1,
#  'fastq_groomer,bowtie2,deeptools_bamCoverage': 1,
#  'fastq_groomer,bismark_bowtie2': 1,
#  'tophat2,cufflinks,cuffmerge,cuffcompare': 1,
#  'tophat2,cuffmerge,cuffcompare': 1,
#  'ncbi_tblastn_wrapper,Filter1,Add_a_column1,Cut1,gops_intersect_1,sort1,Grouping1': 1,
#  'cutadapt,trim_galore,fastq_groomer,tophat2': 1,
#  'cutadapt,trim_galore,fastqc': 1,
#  'trim_galore,tophat2,samtools_rmdup,deeptools_bamCorrelate': 1,
#  'trim_galore,bismark_bowtie,samtools_rmdup,sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,smooth_running_window,bedtools_intersectbed,Cut1,methtools_dmr': 1,
#  'trim_galore,bismark_bowtie,samtools_rmdup,sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,smooth_running_window,Cut1,methtools_dmr': 1,
#  'trim_galore,bismark_bowtie,samtools_rmdup,sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,Cut1,methtools_dmr': 1,
#  'trim_galore,bismark_bowtie,samtools_rmdup,sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,smooth_running_window,bedtools_intersectbed,Cut1,wig_to_bigWig': 1,
#  'trim_galore,bismark_bowtie,samtools_rmdup,sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,smooth_running_window,Cut1,wig_to_bigWig': 1,
#  'trim_galore,bismark_bowtie,samtools_rmdup,sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,Cut1,wig_to_bigWig': 1,
#  'samtools_sort,htseq-count,deseq2,Filter1,Show beginning1,hgv_david': 1,
#  'trim_galore,tophat2,cufflinks,cuffmerge,CONVERTER_gff_to_bed_0': 1,
#  'tophat2,htseq_count,deseq2_single': 1,
#  'Grep1,Convert characters1,tab2fasta,EMBOSS: transeq101': 1,
#  'trim_galore,tophat2,samtools_sort,htseq_count,deseq2_single,Filter1': 1,
#  'trim_galore,fastqc,cshl_awk_tool': 1,
#  'tp_cut_tool,bedtools_intersectbed,Grouping1,tp_multijoin_tool,Add_a_column1,Filter1,join1': 1,
#  'sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,smooth_running_window,bedtools_intersectbed,Cut1,methtools_dmr': 1,
#  'sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,smooth_running_window,Cut1,methtools_dmr': 1,
#  'sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,Cut1,methtools_dmr': 1,
#  'sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,smooth_running_window,bedtools_intersectbed,Cut1,wig_to_bigWig': 1,
#  'sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,smooth_running_window,Cut1,wig_to_bigWig': 1,
#  'sam_merge2,samtools_sort,methtools_calling,sort1,methtools_destrand,Filter1,Cut1,wig_to_bigWig': 1,
# ...
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,extract_bcs.py,flexbardsc,hisat2,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,coords2clnt.py,piranha': 1,
#  'tp_sed_tool,tp_awk_tool,flexbardsc,hisat2,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,coords2clnt.py,piranha': 1,
#  'hisat2,samtools_flagstat': 1,
#  'flexbar_no_split,extract_bcs.py,merge_pcr_duplicates.py,rm_spurious_events.py,wc_gnu,tp_awk_tool,flexbardsc,hisat2,bamFilter,samtools_sort,picard_FilterSamReads': 1,
#  'flexbar_no_split,extract_bcs.py,flexbar_split_RR_bcs,flexbardsc,hisat2,bamFilter,samtools_sort,picard_FilterSamReads': 1,
#  'flexbar_no_split,extract_bcs.py,convert_bc_to_binary_RY.py,flexbar_split_RR_bcs,flexbardsc,hisat2,bamFilter,samtools_sort,picard_FilterSamReads': 1,
#  'flexbar_no_split,extract_bcs.py,flexbardsc,hisat2,bamFilter,samtools_sort,picard_FilterSamReads': 1,
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,flexbardsc,hisat2,bamFilter,samtools_sort,picard_FilterSamReads': 1,
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,extract_bcs.py,merge_pcr_duplicates.py,rm_spurious_events.py,wc_gnu,tp_awk_tool,flexbardsc,hisat2,bamFilter,samtools_sort,picard_FilterSamReads': 1,
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,extract_bcs.py,flexbardsc,hisat2,bamFilter,samtools_sort,picard_FilterSamReads': 1,
#  'tp_sed_tool,tp_awk_tool,flexbardsc,hisat2,bamFilter,samtools_sort,picard_FilterSamReads': 1,
#  'cshl_fastx_clipper,bowtie2,ngsutils_bam_filter,bam_to_sam,tp_awk_tool,sam_to_bam,bedtools_bamtobed,bedtools_slopbed,Extract genomic DNA 1': 1,
#  'cshl_fastx_clipper,bowtie2,ngsutils_bam_filter,bam_to_sam,tp_awk_tool,sam_to_bam,bedtools_bamtobed,bedtools_slopbed,bedtools_mergebed,Extract genomic DNA 1,DatamashOps': 1,
#  'cshl_fastx_clipper,bowtie2,ngsutils_bam_filter,bam_to_sam,tp_awk_tool,sam_to_bam,bedtools_bamtobed,bedtools_slopbed,Extract genomic DNA 1,DatamashOps': 1,
#  'cshl_awk_tool,tp_replace_in_line,tp_replace_in_column,gops_intersect_1': 1,
#  'cshl_awk_tool,tp_replace_in_line,tp_replace_in_column,CONVERTER_interval_to_bed_0,get_flanks1,gops_intersect_1': 1,
#  'cshl_awk_tool,tp_tac,tp_replace_in_line,tp_replace_in_column,gops_intersect_1': 1,
#  'cshl_awk_tool,tp_tac,tp_replace_in_line,tp_replace_in_column,CONVERTER_interval_to_bed_0,get_flanks1,gops_intersect_1': 1,
#  'get_flanks1,gops_intersect_1,tp_tac,Count1,charts': 1,
#  'get_flanks1,tp_tac,Count1,charts': 1,
#  'get_flanks1,gops_intersect_1,tp_tac,Count1,DatamashOps': 1,
#  'get_flanks1,tp_tac,Count1,DatamashOps': 1,
#  'cshl_awk_tool,tp_replace_in_line,tp_tac,CONVERTER_interval_to_bed_0': 1,
#  'cshl_awk_tool,tp_tac,tp_replace_in_line,CONVERTER_interval_to_bed_0': 1,
#  'cshl_awk_tool,tp_tac,tp_replace_in_line,gops_intersect_1,Count1': 1,
#  'tp_replace_in_column,tp_find_and_replace,CONVERTER_interval_to_bed_0': 1,
#  'cshl_awk_tool,tp_tail_tool': 1,
#  'tp_replace_in_column,tp_find_and_replace,gops_intersect_1,Count1,barchart_gnuplot': 1,
#  'cshl_awk_tool,CONVERTER_interval_to_bed_0': 1,
#  'get_flanks1,gops_intersect_1,Count1,DatamashOps': 1,
#  'cshl_awk_tool,tp_find_and_replace,gops_intersect_1,Count1,DatamashOps': 1,
#  'tp_tac,CONVERTER_interval_to_bed_0': 1,
#  'tp_find_and_replace,CONVERTER_interval_to_bed_0': 1,
#  'tp_find_and_replace,gops_intersect_1,Count1': 1,
#  'cshl_awk_tool,tp_replace_in_line,tp_tac,gops_intersect_1,Count1': 1,
#  'cshl_awk_tool,tp_replace_in_column,CONVERTER_interval_to_bed_0,gops_intersect_1,Count1': 1,
#  'cshl_awk_tool,tp_replace_in_column,tp_tac,CONVERTER_interval_to_bed_0': 1,
#  'tp_replace_in_line,tp_tac': 1,
#  'flexbar_no_split,extract_bcs.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,wc_gnu,tp_awk_tool,cat1': 1,
#  'flexbar_no_split,extract_bcs.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,wc_gnu,tp_awk_tool,cat1': 1,
#  'flexbar_no_split,extract_bcs.py,convert_bc_to_binary_RY.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,wc_gnu,tp_awk_tool,cat1': 1,
#  'flexbar_no_split,extract_bcs.py,convert_bc_to_binary_RY.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,wc_gnu,tp_awk_tool,cat1': 1,
#  'flexbar_no_split,extract_bcs.py,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,wc_gnu,tp_awk_tool,cat1': 1,
#  'flexbar_no_split,extract_bcs.py,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,wc_gnu,tp_awk_tool,cat1': 1,
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,wc_gnu,tp_awk_tool,cat1': 1,
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,wc_gnu,tp_awk_tool,cat1': 1,
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,extract_bcs.py,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,wc_gnu,tp_awk_tool,cat1': 1,
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,extract_bcs.py,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,wc_gnu,tp_awk_tool,cat1': 1,
#  'flexbar_no_split,extract_bcs.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,coords2clnt.py': 1,
#  'flexbar_no_split,extract_bcs.py,convert_bc_to_binary_RY.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,coords2clnt.py': 1,
#  'flexbar_no_split,extract_bcs.py,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,coords2clnt.py': 1,
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,coords2clnt.py': 1,
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,extract_bcs.py,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,coords2clnt.py': 1,
#  'tp_sed_tool,tp_awk_tool,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,coords2clnt.py': 1,
#  'flexbar_no_split,extract_bcs.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig': 1,
#  'flexbar_no_split,extract_bcs.py,convert_bc_to_binary_RY.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig': 1,
#  'flexbar_no_split,extract_bcs.py,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig': 1,
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig': 1,
#  'flexbar_no_split,remove_tail.py,flexbar_split_RR_bcs,extract_bcs.py,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig': 1,
#  'tp_sed_tool,tp_awk_tool,flexbardsc,secretbt2test,ngsutils_bam_filter,extract_aln_ends.py,merge_pcr_duplicates.py,rm_spurious_events.py,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig': 1,
#  'bam_to_sam,Count1': 1,
#  'Show beginning1,hgv_david': 1,
#  'trim_galore,hisat2,cufflinks,cuffmerge,cuffcompare': 1,
#  'deseq2,Filter1,tp_cut_tool,venn_list': 1,
#  'deseq2,Filter1,tp_head_tool,hgv_david': 1,
#  'macs2_callpeak,bedtools_getfastabed,tp_tail_tool,meme_fimo': 1,
#  'macs2_callpeak,bedtools_getfastabed,tp_tail_tool,meme_meme,meme_fimo': 1,
#  'macs2_callpeak,bg_uniq': 1,
#  'trim_galore,bowtie2,deeptools_plot_fingerprint': 1,
#  'Filter1,random_lines1': 1,
#  'pileometh,Remove beginning1,tp_sort_header_tool,Add_a_column1,Cut1': 1,
#  'trim_galore,tophat2,samtools_rmdup,cuffdiff,Filter1': 1,
#  'trim_galore,tophat2,samtools_rmdup,htseq_count,deseq2,Filter1': 1,
#  'trim_galore,tophat2,samtools_rmdup,cuffnorm': 1,
#  'Filter1,random_lines1,tp_cat': 1,
#  'Extract genomic DNA 1,tp_awk_tool,tp_cat,bedtools_sortbed': 1,
#  'genbank_to_gff,Remove beginning1,Filter1,cat1': 1,
#  'Filter1,cat1': 1,
#  'Filter1,tp_sort_header_tool,tp_head_tool,tp_cat': 1,
#  'tp_cat,Grouping1,tp_sort_header_tool,tab2fasta,tp_awk_tool': 1,
#  'bowtie2,seq_filter_by_mapping,sailfish,tp_sort_header_tool': 1,
#  'bg_protein_properties,Summary_Statistics1,cat1,Paste1': 1,
#  'Extract genomic DNA 1,tp_awk_tool,tp_cat,bedtools_sortbed,tp_cut_tool': 1,
#  'fastq_to_tabular,Filter1,tabular_to_fastq,fastqc': 1,
#  'wolf_psort,Filter1,trimmer,tp_easyjoin_tool,comp1,bg_uniq': 1,
#  'trim_galore,extract_bcs.py,merge_pcr_duplicates.py,rm_spurious_events.py,coords2clnt.py,tp_cat': 1,
#  'trim_galore,extract_bcs.py,merge_pcr_duplicates.py,rm_spurious_events.py,wc_gnu,tp_awk_tool,tp_cat': 1,
#  'trim_galore,extract_bcs.py,secretbt2test,ngsutils_bam_filter,bam_to_sam,tp_awk_tool,sam_to_bam,bedtools_bamtobed,merge_pcr_duplicates.py,rm_spurious_events.py,coords2clnt.py,tp_cat': 1,
#  'trim_galore,extract_bcs.py,secretbt2test,ngsutils_bam_filter,bam_to_sam,tp_awk_tool,tp_cat': 1,
#  'trim_galore,extract_bcs.py,secretbt2test,samtools_flagstat,tp_awk_tool,sam_to_bam,bedtools_bamtobed,merge_pcr_duplicates.py,rm_spurious_events.py,coords2clnt.py,tp_cat': 1,
#  'trim_galore,extract_bcs.py,secretbt2test,samtools_flagstat,tp_awk_tool,tp_cat': 1,
#  'trim_galore,extract_bcs.py,merge_pcr_duplicates.py,rm_spurious_events.py,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig': 1,
#  'trim_galore,extract_bcs.py,secretbt2test,ngsutils_bam_filter,bam_to_sam,tp_awk_tool,sam_to_bam,bedtools_bamtobed,merge_pcr_duplicates.py,rm_spurious_events.py,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig': 1,
#  'trim_galore,extract_bcs.py,secretbt2test,samtools_flagstat,tp_awk_tool,sam_to_bam,bedtools_bamtobed,merge_pcr_duplicates.py,rm_spurious_events.py,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig': 1,
#  'trim_galore,hisat2,samtools_rmdup,samtools_flagstat': 1,
#  'sailfish,tp_tail_tool,Filter1': 1,
#  'tp_cat,bedtools_sortbed,bedtools_genomecoveragebed_bedgraph,tp_sed_tool': 1,
#  'Extract genomic DNA 1,tp_split_on_column,tp_awk_tool,rnafold,tp_cat': 1,
#  'tp_awk_tool,Paste1': 1,
#  'fasta2tab,Paste1': 1,
#  'Remove beginning1,tp_sort_header_tool,Paste1,Cut1,DatamashOps': 1,
#  'Remove beginning1,tp_sort_header_tool,Cut1,DatamashOps': 1,
#  'fastq_groomer,trim_galore,bowtie2': 1,
#  'hisat2,seq_filter_by_mapping,fastq_to_fasta_python,fasta_filter_by_length,ncbi_blastn_wrapper,Grep1': 1,
#  'uniprot,signalp3': 1,
#  'gops_intersect_1,Convert characters1,Count1': 1,
#  'tp_find_and_replace,Add_a_column1,Cut1': 1,
#  'trim_galore,tophat2,ngsutils_bam_filter,bedtools_intersectbed,deeptools_bam_coverage': 1,
#  'trim_galore,tophat2,ngsutils_bam_filter,htseq_count': 1,
#  'trim_galore,tophat2,samtools_rmdup,bedtools_intersectbed,deeptools_bam_coverage': 1,
#  'tp_find_and_replace,Filter1,Add_a_column1,Cut1,cat1,tp_sort_header_tool': 1,
#  'trim_galore,tophat2,bedtools_intersectbed,deeptools_bam_coverage': 1,
#  'tophat2,bam_to_sam,Count1': 1,
#  'tophat2,ngsutils_bam_filter,samtools_flagstat': 1,
#  'sklearn_numeric_clustering,Paste1': 1,
#  'eden_sequence_converter,eden_vectorizer,sklearn_numeric_clustering,Paste1': 1,
#  'trim_galore,tophat2,samtools_rmdup,ngsutils_bam_filter,bedtools_intersectbed,deeptools_bam_coverage': 1,
#  'trim_galore,tophat2,samtools_rmdup,ngsutils_bam_filter,htseq_count': 1,
#  'Cut1,bedtools_intersectbed,Grouping1,DatamashOps,tp_cat': 1,
#  'wolf_psort,Filter1,tp_cut_tool': 1,
#  'ngsutils_bam_filter,bedtools_bamtofastq,tophat2,samtools_flagstat': 1,
#  'ngsutils_bam_filter,bedtools_bamtofastq,tophat2,samtools_rmdup,samtools_flagstat': 1,
#  'ngsutils_bam_filter,bedtools_bamtofastq,tophat2,samtools_rmdup,picard_MergeSamFiles,samtools_flagstat': 1,
#  'ngsutils_bam_filter,bedtools_bamtofastq,tophat2,samtools_rmdup,picard_MergeSamFiles': 1,
#  'bam_to_sam,Filter1,samtools_flagstat': 1,
#  'tp_unfold_column_tool,Remove beginning1,join1,Cut1,tp_cat,Filter1': 1,
#  'tp_unfold_column_tool,uniprot,Remove beginning1,join1,Cut1,tp_cat,Filter1': 1,
#  'tp_cut_tool,join1,Cut1,tp_cat,Filter1': 1,
#  'bedtools_bamtofastq,tophat2': 1,
#  'trim_galore,tophat2,samtools_rmdup,ngsutils_bam_filter,picard_MergeSamFiles,bedtools_intersectbed,deeptools_bam_coverage': 1,
#  'trim_galore,tophat2,samtools_rmdup,picard_MergeSamFiles,bedtools_intersectbed,deeptools_bam_coverage': 1,
#  'trim_galore,tophat2,samtools_rmdup,ngsutils_bam_filter,picard_MergeSamFiles,htseq_count': 1,
#  'trim_galore,tophat2,samtools_rmdup,picard_MergeSamFiles,htseq_count': 1,
#  'ngsutils_bam_filter,bedtools_bamtofastq,tophat2,samtools_rmdup,picard_MergeSamFiles,bedtools_intersectbed,deeptools_bam_coverage': 1,
#  'ngsutils_bam_filter,picard_MergeSamFiles,bedtools_intersectbed,deeptools_bam_coverage': 1,
#  'ngsutils_bam_filter,bedtools_bamtofastq,tophat2,samtools_rmdup,picard_MergeSamFiles,htseq_count': 1,
#  'ngsutils_bam_filter,picard_MergeSamFiles,htseq_count': 1,
#  'bed2gff1,Remove beginning1,tp_replace_in_column,Cut1': 1,
#  'bedtools_windowbed,Add_a_column1,tp_sed_tool,mergeCols1,comp1,Cut1': 1,
#  'wolf_psort,Filter1,tp_easyjoin_tool,tp_cut_tool': 1,
#  'bowtie2,samtools_sort,picard_MarkDuplicates,deeptools_bam_coverage,deeptools_computeMatrix,deeptools_heatmapper': 1,
#  'tp_cut_tool,gtf_filter_by_attribute_values_list,Extract genomic DNA 1': 1,
#  'tp_awk_tool,gtf_filter_by_attribute_values_list,Extract genomic DNA 1': 1,
#  'tp_grep_tool,Count1,tp_cat': 1,
#  'tp_grep_tool,Count1,wc_gnu,tp_cat': 1,
#  'mergeCols1,addValue,Cut1,bedtools_intersectbed,Grouping1': 1,
#  'cuffcompare,Filter1': 1,
#  'uniprot,bg_protein_properties,Summary_Statistics1,cat1,Paste1': 1,
#  'tp_awk_tool,bedtools_intersectbed,tp_cut_tool,tp_head_tool': 1,
#  'tp_awk_tool,bedtools_intersectbed,tp_cut_tool,Remove beginning1,tp_head_tool': 1,
#  'bedtools_sortbed,bedtools_bedtobam': 1,
#  'tp_sort_header_tool,bedtools_bedtobam': 1,
#  'bedtools_sortbed,bedtools_bedtobam,bam_to_sam,htseq_count,deseq2,tp_sort_header_tool,blockbuster,p_clip_peaks,tp_awk_tool,comp1': 1,
#  'bedtools_sortbed,bedtools_bedtobam,bam_to_sam,htseq_count,deseq2,tp_sort_header_tool,Filter1,comp1': 1,
#  'bedtools_sortbed,tp_cat,DatamashOps,tp_awk_tool,tp_sort_header_tool,Filter1,comp1': 1,
#  'bedtools_sortbed,tp_cat,DatamashOps,tp_awk_tool,htseq_count,deseq2,tp_sort_header_tool,Filter1,comp1': 1,
#  'bedtools_sortbed,tp_cat,DatamashOps,tp_awk_tool,comp1': 1,
#  'Remove beginning1,join1,tp_cut_tool,tp_sorted_uniq,tp_sort_header_tool,tp_sed_tool': 1,
#  'join1,tp_cut_tool,tp_sorted_uniq,tp_sort_header_tool,tp_sed_tool': 1,
#  'fastq_groomer,trim_galore,bowtie2,samtools_rmdup': 1,
#  'bedtools_bamtobed,get_flanks1,gops_intersect_1': 1,
#  'Cut1,picard_FilterSamReads': 1,
#  'bedtools_bamtobed,Filter1,get_flanks1,bedtools_genomecoveragebed_bedgraph,wig_to_bigWig': 1,
#  'Grouping1,cat1': 1,
#  'addValue,gops_intersect_1': 1,
#  'Cut1,gops_intersect_1': 1,
#  'Cut1,get_flanks1': 1,
#  'Cut1,get_flanks1,gops_join_1,Add_a_column1,Grouping1,cat1': 1,
#  'Cut1,get_flanks1,gops_intersect_1,Add_a_column1,Grouping1,cat1': 1,
#  'comp1,gops_intersect_1,Add_a_column1,Grouping1,cat1': 1,
#  'get_flanks1,deeptools_compute_matrix,Paste1': 1,
#  'get_flanks1,deeptools_compute_matrix,Remove beginning1,Paste1': 1,
#  'trim_galore,tophat2,htseq_count,deseq2,Filter1': 1,
#  'trim_galore,cshl_fastx_barcode_splitter': 1,
#  'fastq_groomer,cutadapt,cshl_fastx_barcode_splitter': 1,
#  ...}
