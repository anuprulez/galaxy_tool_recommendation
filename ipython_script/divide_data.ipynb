# %%
import pandas as pd

path = "data/wfc-04-2020.tsv"

df = pd.read_csv(path, sep="\t", header=None, index_col=None)

# %%
df
# Out:
#            0                           1       2   \
# 0           3  2013-02-07 16:48:46.721866       5
# 1           3  2013-02-07 16:48:46.721866       6
# 2           3  2013-02-07 16:48:46.721866       7
# 3           3  2013-02-07 16:48:46.721866       7
# 4           3  2013-02-07 16:48:46.721866       8
# ...       ...                         ...     ...
# 746134  50779  2020-04-27 14:36:39.197104  727112
# 746135  50779  2020-04-27 14:36:39.197104  727111
# 746136  50779  2020-04-27 14:36:39.197104  727110
# 746137  50779  2020-04-27 14:36:39.197104  727108
# 746138  50779  2020-04-27 14:36:39.197104  727108
#
#                                                        3      4       5   \
# 0                                                   Grep1  1.0.1       7
# 1                                                    Cut1  1.0.1       8
# 2                                       Remove beginning1  1.0.0       9
# 3                                       Remove beginning1  1.0.0       6
# 4                                                addValue  1.0.0      11
# ...                                                   ...    ...     ...
# 746134                                               Cut1    NaN  727113
# 746135  toolshed.g2.bx.psu.edu/repos/devteam/column_ma...    NaN  727112
# 746136  toolshed.g2.bx.psu.edu/repos/devteam/column_ma...    NaN  727111
# 746137                                                NaN    NaN  727114
# 746138                                                NaN    NaN  727113
#
#                                                        6      7  8  9    10
# 0                                       Remove beginning1  1.0.0  f  t    f
# 1                                                addValue  1.0.0  f  t    f
# 2                                                    Cut1  1.0.1  f  t    f
# 3                                                    Cut1  1.0.1  f  t    f
# 4                                                  Paste1  1.0.0  f  t    f
# ...                                                   ...    ... .. ..  ...
# 746134  toolshed.g2.bx.psu.edu/repos/devteam/intersect...    NaN  f  f  NaN
# 746135                                               Cut1    NaN  f  f  NaN
# 746136  toolshed.g2.bx.psu.edu/repos/devteam/column_ma...    NaN  f  f  NaN
# 746137  toolshed.g2.bx.psu.edu/repos/devteam/intersect...    NaN  f  f  NaN
# 746138  toolshed.g2.bx.psu.edu/repos/devteam/intersect...    NaN  f  f  NaN
#
# [746139 rows x 11 columns]

# %%
df_new = df[100000:200000]

df_new.to_csv("data/worflow-connection-subset-04-20.tsv", sep="\t", header=None, index=None)
