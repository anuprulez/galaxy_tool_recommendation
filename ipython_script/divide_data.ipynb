# %%
import pandas as pd

path = "data/gxadmin_wf_conn.tsv"

df = pd.read_csv(path, sep="\t")

# %%
df
# Out:
#             5  2013-02-07 16:49:04.367628      27  \
# 0           5  2013-02-07 16:49:04.367628      39
# 1           5  2013-02-07 16:49:04.367628      49
# 2           5  2013-02-07 16:49:04.367628      60
# 3           5  2013-02-07 16:49:04.367628      62
# 4          11  2013-02-07 17:03:54.795316     139
# ...       ...                         ...     ...
# 320378  39075  2019-11-19 16:32:55.062139  592026
# 320379  39077  2019-11-19 16:50:55.654888  592053
# 320380  39084  2019-11-19 17:22:42.874235  592159
# 320381  39084  2019-11-19 17:22:42.874235  592159
# 320382  39084  2019-11-19 17:22:42.874235  592165
#
#                                                      Cut1          1.0.1  \
# 0                                                 Filter1          1.1.0
# 1                                     Summary_Statistics1          1.1.0
# 2                                                  Paste1          1.0.0
# ...

# %%
df_new = df[:10000]

df_new.to_csv("data/worflow-connection-04-20-10000.tsv", sep="\t", header=None)
